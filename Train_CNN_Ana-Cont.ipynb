# %% [markdown]
# # CNN Training
#
# Target of this code is to train a CNN network to extract the needle position of an analog needle device.
#
# ### Preparing the training
# * First all libraries are loaded
#     * It is assumed, that they are installed during the Python setup
# * matplotlib is set to print the output inline in the jupyter notebook

# %%
########### Basic Parameters for Running: ################################
    
TFliteNamingAndVersion = "ana-cont_1200_s2"   # Used for tflite Filename
Training_Percentage = 0.2              # 0.0 = Use all Images for Training
Batch_Size = 32
Epoch_Anz = 400
input_shape = (32,32,3)

##########################################################################



from absl import app as absl_app
from absl import flags
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import numpy as np
from sklearn.utils import shuffle
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Conv2D, MaxPool2D, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import History 
import math
from PIL import Image 

FileName = TFliteNamingAndVersion + "_qs" + ".tflite"


loss_ges = np.array([])
val_loss_ges = np.array([])

# %matplotlib inline
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load training data
# * The data is expected in the "Input_dir"
# * Picture size must be 32x32 with 3 color channels (RGB)
# * The filename contains the informations needed for training in the first 3 digits::
# * Typical filename:
#     * x.y-zzzz.jpg
#     * e.g. "4.6_Lfd-1406_zeiger3_2019-06-02T050011"
#
# |Place holder | Meaning                     | Usage        |
# |------------- |-----------------------------|--------------|
# | **x.y**          | readout value               | **to be learned** |
# | zzzz        | additional information              | not needed   |
#
# * The images are stored in the x_data[]
# * The expected output for each image in the corresponding y_data[]
#     * The periodic nature is reflected in a **sin/cos coding**, which allows to restore the angle/counter value with an arctan later on.
#
# * The last step is a shuffle (from sklearn.utils) as the filenames are on order due to the encoding of the expected analog readout in the filename

# %%
Input_dir='data_resize_all'

files = glob.glob("data_raw_all" + '/*.jpg')
y_data = np.empty((len(files)))
y_cont = np.empty((len(files),2))
f_data = np.empty((len(files)), dtype="<U250")
x_data = np.empty((len(files),input_shape[0],input_shape[1],input_shape[2]))

for i, aktfile in enumerate(files):
    base = os.path.basename(aktfile)

    # get label from filename (1.2_ new or 1_ old),
    if (base[1]=="."):
        target = base[0:3]
    else:
        target = base[0:1]
    category = float(target)
    target_number = (float(base[0:3])) / 10
    target_sin = math.sin(target_number * math.pi * 2)
    target_cos = math.cos(target_number * math.pi * 2)

    zw = np.array([target_sin, target_cos])
    
    test_image = Image.open(aktfile).resize((input_shape[0],input_shape[1]), Image.Resampling.NEAREST)
    test_image = np.array(test_image, dtype="float32")
    f_data[i] =  aktfile
    x_data[i] = test_image
    y_cont[i] =  zw
    y_data[i] = category
    
    
print("Analog data count: ", len(y_data))  

#x_data = np.array(x_data).astype(np.floa<t32)
#y_data = np.array(y_data)
#y_data = np.expand_dims(y_data, -1)#.astype(np.int8)
print(x_data.shape)

x_data, y_data, f_data, y_cont = shuffle(x_data, y_data, f_data, y_cont)
X_train, X_test, y_train, y_test = train_test_split(x_data, y_cont, test_size=Training_Percentage)

#y_train = [np.sin(y_train * np.pi * 2), np.cos(y_train * np.pi * 2)]
#y_test = [np.sin(y_test * np.pi * 2), np.cos(y_test * np.pi * 2)]
#y_train = keras.utils.to_categorical(y_train, 100)
#y_test = keras.utils.to_categorical(y_test, 100)

print(y_cont.shape)
# Out:
# Analog data count:  6661
# (6661, 32, 32, 3)
# (6661, 2)

# %% [markdown]
# ### Distribution of the data
#
# Uneven distribution of data can lead to poorer results.
#
# In some classes (8.4) we have only 20 images. In other classes over 100 images.

# %%
_, inverse = np.unique(y_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
fig = plt.figure(figsize=(40, 10))
fig.suptitle("Distribution of data")
plt.bar(np.arange (0, 100/10, 0.1), ziffer_bincount, width=0.09, align='center')
plt.ylabel('count')
plt.xlabel('digit class')
plt.tight_layout()
_ = plt.xticks(np.arange(0, 100/10, 0.1))

# %% [markdown]
# ### Define the model
#
# The layout of the network ist a typcial CNN network with alternating 2x **Conv2D**, **BatchNormalization** and **MaxPool2D** layers. Finished after **flattening** with additional **Dense** layer.
#
# **Dropout** between CNN layers are 0.2, between fully connected layers 0.4, but only the fully connected output layer.
#
# * Shape of the input layer: (32, 32, 3)
# * Shape of the output layer: (100) - classification 0.0 ... 9.9

# %%
inputs = tf.keras.Input(shape=(32, 32, 3))
inputs2 = tf.keras.layers.BatchNormalization()(inputs)
inputs3 = tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation="relu")(inputs2)
inputs3_1 = tf.keras.layers.BatchNormalization()(inputs3)
inputs4 = tf.keras.layers.MaxPool2D(pool_size=(4,4))(inputs3_1)
inputs4_1 = tf.keras.layers.Dropout(0.15)(inputs4)
inputs5 = tf.keras.layers.Conv2D(16, (5, 5), padding='same', activation="relu")(inputs4_1)
inputs5_1 = tf.keras.layers.BatchNormalization()(inputs5)
inputs6 = tf.keras.layers.MaxPool2D(pool_size=(2,2))(inputs5_1)
inputs6_1 = tf.keras.layers.Dropout(0.15)(inputs6)
inputs7 = tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation="relu")(inputs6_1)
inputs7_1 = tf.keras.layers.BatchNormalization()(inputs7)
inputs8 = tf.keras.layers.MaxPool2D(pool_size=(2,2))(inputs7_1)
inputs9 = tf.keras.layers.Flatten()(inputs8)

inputs10 = tf.keras.layers.Dense(128,activation="relu")(inputs9)
inputs11 = tf.keras.layers.Dense(64,activation="relu")(inputs10)
output = tf.keras.layers.Dense(2)(inputs11)

model = tf.keras.Model(inputs=inputs, outputs=output)

model.compile(loss=keras.losses.mean_squared_error, optimizer=tf.keras.optimizers.Adam(
    learning_rate=1e-3), metrics = ["accuracy"])

model.summary()
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  batch_normalization (BatchN  (None, 32, 32, 3)        12
#  ormalization)
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        2432
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 32)         0
#  )
#
#  dropout (Dropout)           (None, 8, 8, 32)          0
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          12816
#
#  batch_normalization_2 (Batc  (None, 8, 8, 16)         64
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 16)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 32)          4640
#
#  batch_normalization_3 (Batc  (None, 4, 4, 32)         128
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 45,118
# Trainable params: 44,952
# Non-trainable params: 166
# _________________________________________________________________
# 2023-03-24 00:05:15.603807: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-24 00:05:15.603921: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# # Training
# The input pictures are randomly scattered for brightness and pixel shift variations. These is implemented with a ImageDataGenerator.
#
#
# The training is in one step.
#
# The best model will be stored as \<modelname\>_best.h5

# %% [markdown]
# ### Augmentation
#
# Augmentation uses shift, zoom, brightness, shear

# %%
from numpy import pi
import random

Shift_Range = 1/32
Zoom_Range = 0.05
Brightness_Range = 0.3
ShearRange= 3
Rotation_Range=2

def add_noise(img):
    '''Add random noise to an image'''
    VARIABILITY = 3
    deviation = VARIABILITY*random.random()
    noise = np.random.normal(0, deviation, img.shape)
    img += noise
    np.clip(img, 0., 255.)
    return img

datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
                height_shift_range=[-Shift_Range,Shift_Range],
                brightness_range=[1-Brightness_Range,1+Brightness_Range],
                zoom_range=Zoom_Range,
                shear_range=ShearRange,
                rotation_range=Rotation_Range,
                #preprocessing_function=add_noise
                #rescale=1/255
                )
datagen_val = ImageDataGenerator()
train_iterator = datagen.flow(X_train, y_train, batch_size=Batch_Size)
validation_iterator = datagen_val.flow(X_test, y_test, batch_size=Batch_Size)


columns=4
rows=3

fig = plt.figure(figsize=(18, 11))
for i in range(1, columns*rows +1):
    img, label = train_iterator.next()
    prediction = ((np.arctan2(label[0][0], label[0][1])/(2*math.pi)) % 1)*10
    ax0 = fig.add_subplot(rows, columns, i)
    plt.title("{:10.1f}\n".format(prediction))  # set title
    plt.imshow(img[0].astype(np.uint8))
    plt.axis('off')
    ax=plt.gca()
    ax.get_xaxis().set_visible(False) 
    ax2 = fig.add_subplot(rows, columns, i, polar=True, label="polar")
    ax2.set_facecolor("None")
    # suppress the radial labels
    plt.setp(ax.get_yticklabels(), visible=False)

    # set the circumference labels
    ax2.set_xticks(np.linspace(0, 2*pi, 10, endpoint=False))
    ax2.set_xticklabels(range(10))
    ax2.yaxis.grid(False)
    
    # make the labels go clockwise
    ax2.set_theta_direction(-1)
    # place 0 at the top
    ax2.set_theta_offset(pi/2.0)    
    ax2.set_yticklabels([])


    # plt.grid('off')

    # put the points on the circumference
    plt.ylim(0,1)
plt.show()

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau
earlystop = EarlyStopping(monitor='val_loss', mode='min' , patience=30, verbose=1,  restore_best_weights=True)
mc = ModelCheckpoint(TFliteNamingAndVersion + '_best.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True, initial_value_threshold=.03)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=5, min_lr=1e-5, verbose=1)
history = model.fit(train_iterator, 
            validation_data=validation_iterator, 
            batch_size=Batch_Size, 
            epochs = Epoch_Anz,
            callbacks=[earlystop, mc, reduce_lr],
            verbose=1)
# Out:
# Epoch 1/400
# 2023-03-24 00:05:17.199176: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-24 00:05:17.505962: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 167/167 [==============================] - ETA: 0s - loss: 0.4332 - accuracy: 0.6635
# 2023-03-24 00:05:20.535913: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss did not improve from 0.03000
# 167/167 [==============================] - 4s 18ms/step - loss: 0.4332 - accuracy: 0.6635 - val_loss: 0.3162 - val_accuracy: 0.8012 - lr: 0.0010
# Epoch 2/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.2024 - accuracy: 0.8345
# Epoch 2: val_loss did not improve from 0.03000
# 167/167 [==============================] - 3s 16ms/step - loss: 0.2020 - accuracy: 0.8348 - val_loss: 0.1125 - val_accuracy: 0.9077 - lr: 0.0010
# Epoch 3/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.1245 - accuracy: 0.8822
# Epoch 3: val_loss did not improve from 0.03000
# 167/167 [==============================] - 3s 16ms/step - loss: 0.1243 - accuracy: 0.8829 - val_loss: 0.0875 - val_accuracy: 0.9197 - lr: 0.0010
# Epoch 4/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0945 - accuracy: 0.9010
# Epoch 4: val_loss did not improve from 0.03000
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0941 - accuracy: 0.9024 - val_loss: 0.0689 - val_accuracy: 0.9250 - lr: 0.0010
# Epoch 5/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0779 - accuracy: 0.9201
# Epoch 5: val_loss did not improve from 0.03000
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0781 - accuracy: 0.9195 - val_loss: 0.0673 - val_accuracy: 0.9235 - lr: 0.0010
# Epoch 6/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0648 - accuracy: 0.9274
# Epoch 6: val_loss did not improve from 0.03000
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0651 - accuracy: 0.9276 - val_loss: 0.0521 - val_accuracy: 0.9302 - lr: 0.0010
# Epoch 7/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0594 - accuracy: 0.9241
# Epoch 7: val_loss did not improve from 0.03000
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0593 - accuracy: 0.9240 - val_loss: 0.0458 - val_accuracy: 0.9362 - lr: 0.0010
# Epoch 8/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0535 - accuracy: 0.9328
# Epoch 8: val_loss did not improve from 0.03000
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0534 - accuracy: 0.9324 - val_loss: 0.0521 - val_accuracy: 0.9355 - lr: 0.0010
# Epoch 9/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0484 - accuracy: 0.9366
# Epoch 9: val_loss did not improve from 0.03000
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0483 - accuracy: 0.9366 - val_loss: 0.0310 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 10/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9417
# Epoch 10: val_loss did not improve from 0.03000
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0410 - accuracy: 0.9414 - val_loss: 0.0329 - val_accuracy: 0.9475 - lr: 0.0010
# Epoch 11/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0404 - accuracy: 0.9432
# Epoch 11: val_loss improved from 0.03000 to 0.02433, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0402 - accuracy: 0.9428 - val_loss: 0.0243 - val_accuracy: 0.9647 - lr: 0.0010
# Epoch 12/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9480
# Epoch 12: val_loss did not improve from 0.02433
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0329 - accuracy: 0.9480 - val_loss: 0.0248 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 13/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9504
# Epoch 13: val_loss improved from 0.02433 to 0.02177, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0311 - accuracy: 0.9505 - val_loss: 0.0218 - val_accuracy: 0.9640 - lr: 0.0010
# Epoch 14/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9587
# Epoch 14: val_loss improved from 0.02177 to 0.01794, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0260 - accuracy: 0.9587 - val_loss: 0.0179 - val_accuracy: 0.9670 - lr: 0.0010
# Epoch 15/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 0.9606
# Epoch 15: val_loss improved from 0.01794 to 0.01489, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0220 - accuracy: 0.9600 - val_loss: 0.0149 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 16/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9560
# Epoch 16: val_loss improved from 0.01489 to 0.01447, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0237 - accuracy: 0.9559 - val_loss: 0.0145 - val_accuracy: 0.9737 - lr: 0.0010
# Epoch 17/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0207 - accuracy: 0.9576
# Epoch 17: val_loss did not improve from 0.01447
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0208 - accuracy: 0.9574 - val_loss: 0.0167 - val_accuracy: 0.9782 - lr: 0.0010
# Epoch 18/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9604
# Epoch 18: val_loss improved from 0.01447 to 0.01261, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0174 - accuracy: 0.9604 - val_loss: 0.0126 - val_accuracy: 0.9805 - lr: 0.0010
# Epoch 19/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0156 - accuracy: 0.9683
# Epoch 19: val_loss improved from 0.01261 to 0.01230, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0157 - accuracy: 0.9681 - val_loss: 0.0123 - val_accuracy: 0.9745 - lr: 0.0010
# Epoch 20/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0168 - accuracy: 0.9602
# Epoch 20: val_loss improved from 0.01230 to 0.01128, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0167 - accuracy: 0.9606 - val_loss: 0.0113 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 21/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0150 - accuracy: 0.9677
# Epoch 21: val_loss did not improve from 0.01128
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0150 - accuracy: 0.9677 - val_loss: 0.0126 - val_accuracy: 0.9790 - lr: 0.0010
# Epoch 22/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9667
# Epoch 22: val_loss improved from 0.01128 to 0.01097, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0131 - accuracy: 0.9664 - val_loss: 0.0110 - val_accuracy: 0.9857 - lr: 0.0010
# Epoch 23/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9726
# Epoch 23: val_loss did not improve from 0.01097
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0128 - accuracy: 0.9722 - val_loss: 0.0114 - val_accuracy: 0.9767 - lr: 0.0010
# Epoch 24/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.9704
# Epoch 24: val_loss improved from 0.01097 to 0.00866, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0114 - accuracy: 0.9705 - val_loss: 0.0087 - val_accuracy: 0.9850 - lr: 0.0010
# Epoch 25/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9692
# Epoch 25: val_loss did not improve from 0.00866
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0131 - accuracy: 0.9696 - val_loss: 0.0116 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 26/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9690
# Epoch 26: val_loss did not improve from 0.00866
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0113 - accuracy: 0.9690 - val_loss: 0.0115 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 27/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 0.9656
# Epoch 27: val_loss did not improve from 0.00866
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0130 - accuracy: 0.9657 - val_loss: 0.0097 - val_accuracy: 0.9805 - lr: 0.0010
# Epoch 28/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0124 - accuracy: 0.9702
# Epoch 28: val_loss improved from 0.00866 to 0.00821, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0123 - accuracy: 0.9703 - val_loss: 0.0082 - val_accuracy: 0.9827 - lr: 0.0010
# Epoch 29/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9761
# Epoch 29: val_loss improved from 0.00821 to 0.00775, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0087 - accuracy: 0.9764 - val_loss: 0.0077 - val_accuracy: 0.9850 - lr: 0.0010
# Epoch 30/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0098 - accuracy: 0.9709
# Epoch 30: val_loss improved from 0.00775 to 0.00723, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0098 - accuracy: 0.9709 - val_loss: 0.0072 - val_accuracy: 0.9850 - lr: 0.0010
# Epoch 31/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9739
# Epoch 31: val_loss improved from 0.00723 to 0.00557, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0084 - accuracy: 0.9739 - val_loss: 0.0056 - val_accuracy: 0.9827 - lr: 0.0010
# Epoch 32/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9708
# Epoch 32: val_loss did not improve from 0.00557
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0082 - accuracy: 0.9711 - val_loss: 0.0064 - val_accuracy: 0.9827 - lr: 0.0010
# Epoch 33/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9726
# Epoch 33: val_loss did not improve from 0.00557
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0089 - accuracy: 0.9726 - val_loss: 0.0078 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 34/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9709
# Epoch 34: val_loss did not improve from 0.00557
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0084 - accuracy: 0.9707 - val_loss: 0.0081 - val_accuracy: 0.9835 - lr: 0.0010
# Epoch 35/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9759
# Epoch 35: val_loss did not improve from 0.00557
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0084 - accuracy: 0.9758 - val_loss: 0.0082 - val_accuracy: 0.9895 - lr: 0.0010
# Epoch 36/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0079 - accuracy: 0.9742
# Epoch 36: val_loss did not improve from 0.00557
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0078 - accuracy: 0.9743 - val_loss: 0.0057 - val_accuracy: 0.9902 - lr: 0.0010
# Epoch 37/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9753
# Epoch 37: val_loss did not improve from 0.00557
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0064 - accuracy: 0.9748 - val_loss: 0.0076 - val_accuracy: 0.9790 - lr: 9.0000e-04
# Epoch 38/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9772
# Epoch 38: val_loss did not improve from 0.00557
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0065 - accuracy: 0.9773 - val_loss: 0.0062 - val_accuracy: 0.9857 - lr: 9.0000e-04
# Epoch 39/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 0.9731
# Epoch 39: val_loss did not improve from 0.00557
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0072 - accuracy: 0.9730 - val_loss: 0.0095 - val_accuracy: 0.9842 - lr: 9.0000e-04
# Epoch 40/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9715
# Epoch 40: val_loss did not improve from 0.00557
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0084 - accuracy: 0.9709 - val_loss: 0.0060 - val_accuracy: 0.9797 - lr: 9.0000e-04
# Epoch 41/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9715
# Epoch 41: val_loss did not improve from 0.00557
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0073 - accuracy: 0.9715 - val_loss: 0.0070 - val_accuracy: 0.9715 - lr: 9.0000e-04
# Epoch 42/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9734
# Epoch 42: val_loss did not improve from 0.00557
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0081 - accuracy: 0.9737 - val_loss: 0.0064 - val_accuracy: 0.9842 - lr: 8.1000e-04
# Epoch 43/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9746
# Epoch 43: val_loss improved from 0.00557 to 0.00422, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0064 - accuracy: 0.9748 - val_loss: 0.0042 - val_accuracy: 0.9857 - lr: 8.1000e-04
# Epoch 44/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9730
# Epoch 44: val_loss improved from 0.00422 to 0.00382, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0073 - accuracy: 0.9730 - val_loss: 0.0038 - val_accuracy: 0.9887 - lr: 8.1000e-04
# Epoch 45/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9744
# Epoch 45: val_loss did not improve from 0.00382
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0056 - accuracy: 0.9743 - val_loss: 0.0050 - val_accuracy: 0.9880 - lr: 8.1000e-04
# Epoch 46/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9782
# Epoch 46: val_loss improved from 0.00382 to 0.00378, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0054 - accuracy: 0.9782 - val_loss: 0.0038 - val_accuracy: 0.9887 - lr: 8.1000e-04
# Epoch 47/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9788
# Epoch 47: val_loss did not improve from 0.00378
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0052 - accuracy: 0.9790 - val_loss: 0.0047 - val_accuracy: 0.9857 - lr: 8.1000e-04
# Epoch 48/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9763
# Epoch 48: val_loss did not improve from 0.00378
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0055 - accuracy: 0.9765 - val_loss: 0.0053 - val_accuracy: 0.9767 - lr: 8.1000e-04
# Epoch 49/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9748
# Epoch 49: val_loss did not improve from 0.00378
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0048 - accuracy: 0.9750 - val_loss: 0.0046 - val_accuracy: 0.9887 - lr: 8.1000e-04
# Epoch 50/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9790
# Epoch 50: val_loss did not improve from 0.00378
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0045 - accuracy: 0.9792 - val_loss: 0.0039 - val_accuracy: 0.9887 - lr: 7.2900e-04
# Epoch 51/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9786
# Epoch 51: val_loss did not improve from 0.00378
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0055 - accuracy: 0.9786 - val_loss: 0.0041 - val_accuracy: 0.9827 - lr: 7.2900e-04
# Epoch 52/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.9776
# Epoch 52: val_loss did not improve from 0.00378
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0047 - accuracy: 0.9777 - val_loss: 0.0039 - val_accuracy: 0.9812 - lr: 7.2900e-04
# Epoch 53/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9797
# Epoch 53: val_loss did not improve from 0.00378
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0039 - accuracy: 0.9799 - val_loss: 0.0041 - val_accuracy: 0.9880 - lr: 7.2900e-04
# Epoch 54/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9809
# Epoch 54: val_loss did not improve from 0.00378
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0039 - accuracy: 0.9809 - val_loss: 0.0042 - val_accuracy: 0.9835 - lr: 7.2900e-04
# Epoch 55/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9775
# Epoch 55: val_loss improved from 0.00378 to 0.00376, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0040 - accuracy: 0.9771 - val_loss: 0.0038 - val_accuracy: 0.9880 - lr: 6.5610e-04
# Epoch 56/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9775
# Epoch 56: val_loss did not improve from 0.00376
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0040 - accuracy: 0.9775 - val_loss: 0.0039 - val_accuracy: 0.9910 - lr: 6.5610e-04
# Epoch 57/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9787
# Epoch 57: val_loss did not improve from 0.00376
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0041 - accuracy: 0.9786 - val_loss: 0.0048 - val_accuracy: 0.9895 - lr: 6.5610e-04
# Epoch 58/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9805
# Epoch 58: val_loss did not improve from 0.00376
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0040 - accuracy: 0.9807 - val_loss: 0.0045 - val_accuracy: 0.9865 - lr: 6.5610e-04
# Epoch 59/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9787
# Epoch 59: val_loss did not improve from 0.00376
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0048 - accuracy: 0.9788 - val_loss: 0.0040 - val_accuracy: 0.9835 - lr: 6.5610e-04
# Epoch 60/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9801
# Epoch 60: val_loss did not improve from 0.00376
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0044 - accuracy: 0.9799 - val_loss: 0.0042 - val_accuracy: 0.9902 - lr: 5.9049e-04
# Epoch 61/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 0.9776
# Epoch 61: val_loss improved from 0.00376 to 0.00354, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0052 - accuracy: 0.9777 - val_loss: 0.0035 - val_accuracy: 0.9872 - lr: 5.9049e-04
# Epoch 62/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9771
# Epoch 62: val_loss did not improve from 0.00354
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0044 - accuracy: 0.9767 - val_loss: 0.0040 - val_accuracy: 0.9835 - lr: 5.9049e-04
# Epoch 63/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9823
# Epoch 63: val_loss improved from 0.00354 to 0.00349, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0034 - accuracy: 0.9825 - val_loss: 0.0035 - val_accuracy: 0.9790 - lr: 5.9049e-04
# Epoch 64/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9795
# Epoch 64: val_loss did not improve from 0.00349
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0033 - accuracy: 0.9790 - val_loss: 0.0035 - val_accuracy: 0.9812 - lr: 5.9049e-04
# Epoch 65/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9806
# Epoch 65: val_loss did not improve from 0.00349
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0031 - accuracy: 0.9803 - val_loss: 0.0036 - val_accuracy: 0.9857 - lr: 5.9049e-04
# Epoch 66/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9786
# Epoch 66: val_loss did not improve from 0.00349
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.0005314410547725857.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0041 - accuracy: 0.9784 - val_loss: 0.0049 - val_accuracy: 0.9887 - lr: 5.9049e-04
# Epoch 67/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9808
# Epoch 67: val_loss did not improve from 0.00349
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0050 - accuracy: 0.9807 - val_loss: 0.0039 - val_accuracy: 0.9895 - lr: 5.3144e-04
# Epoch 68/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9781
# Epoch 68: val_loss did not improve from 0.00349
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0038 - accuracy: 0.9780 - val_loss: 0.0044 - val_accuracy: 0.9835 - lr: 5.3144e-04
# Epoch 69/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9807
# Epoch 69: val_loss did not improve from 0.00349
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0033 - accuracy: 0.9807 - val_loss: 0.0041 - val_accuracy: 0.9887 - lr: 5.3144e-04
# Epoch 70/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9823
# Epoch 70: val_loss did not improve from 0.00349
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0033 - accuracy: 0.9825 - val_loss: 0.0041 - val_accuracy: 0.9857 - lr: 5.3144e-04
# Epoch 71/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9793
# Epoch 71: val_loss did not improve from 0.00349
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.00047829695977270604.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0044 - accuracy: 0.9794 - val_loss: 0.0040 - val_accuracy: 0.9872 - lr: 5.3144e-04
# Epoch 72/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9797
# Epoch 72: val_loss improved from 0.00349 to 0.00310, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0033 - accuracy: 0.9797 - val_loss: 0.0031 - val_accuracy: 0.9850 - lr: 4.7830e-04
# Epoch 73/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9832
# Epoch 73: val_loss did not improve from 0.00310
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0031 - accuracy: 0.9831 - val_loss: 0.0035 - val_accuracy: 0.9835 - lr: 4.7830e-04
# Epoch 74/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9839
# Epoch 74: val_loss improved from 0.00310 to 0.00283, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0029 - accuracy: 0.9839 - val_loss: 0.0028 - val_accuracy: 0.9805 - lr: 4.7830e-04
# Epoch 75/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9833
# Epoch 75: val_loss did not improve from 0.00283
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0027 - accuracy: 0.9833 - val_loss: 0.0030 - val_accuracy: 0.9887 - lr: 4.7830e-04
# Epoch 76/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9817
# Epoch 76: val_loss did not improve from 0.00283
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0030 - accuracy: 0.9816 - val_loss: 0.0029 - val_accuracy: 0.9812 - lr: 4.7830e-04
# Epoch 77/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9819
# Epoch 77: val_loss did not improve from 0.00283
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0030 - accuracy: 0.9816 - val_loss: 0.0034 - val_accuracy: 0.9925 - lr: 4.7830e-04
# Epoch 78/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9842
# Epoch 78: val_loss did not improve from 0.00283
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0025 - accuracy: 0.9840 - val_loss: 0.0030 - val_accuracy: 0.9805 - lr: 4.7830e-04
# Epoch 79/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9821
# Epoch 79: val_loss did not improve from 0.00283
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0025 - accuracy: 0.9822 - val_loss: 0.0031 - val_accuracy: 0.9827 - lr: 4.7830e-04
# Epoch 80/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9810
# Epoch 80: val_loss did not improve from 0.00283
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0030 - accuracy: 0.9812 - val_loss: 0.0032 - val_accuracy: 0.9880 - lr: 4.3047e-04
# Epoch 81/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9813
# Epoch 81: val_loss did not improve from 0.00283
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0028 - accuracy: 0.9809 - val_loss: 0.0030 - val_accuracy: 0.9820 - lr: 4.3047e-04
# Epoch 82/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9811
# Epoch 82: val_loss did not improve from 0.00283
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0024 - accuracy: 0.9809 - val_loss: 0.0029 - val_accuracy: 0.9872 - lr: 4.3047e-04
# Epoch 83/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9814
# Epoch 83: val_loss improved from 0.00283 to 0.00242, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0027 - accuracy: 0.9814 - val_loss: 0.0024 - val_accuracy: 0.9835 - lr: 4.3047e-04
# Epoch 84/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9820
# Epoch 84: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0026 - accuracy: 0.9822 - val_loss: 0.0029 - val_accuracy: 0.9850 - lr: 4.3047e-04
# Epoch 85/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9797
# Epoch 85: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0029 - accuracy: 0.9794 - val_loss: 0.0030 - val_accuracy: 0.9865 - lr: 4.3047e-04
# Epoch 86/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9826
# Epoch 86: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0023 - accuracy: 0.9827 - val_loss: 0.0028 - val_accuracy: 0.9827 - lr: 4.3047e-04
# Epoch 87/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9807
# Epoch 87: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0028 - accuracy: 0.9805 - val_loss: 0.0036 - val_accuracy: 0.9805 - lr: 4.3047e-04
# Epoch 88/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9792
# Epoch 88: val_loss did not improve from 0.00242
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.00038742052274756136.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0029 - accuracy: 0.9792 - val_loss: 0.0031 - val_accuracy: 0.9812 - lr: 4.3047e-04
# Epoch 89/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9827
# Epoch 89: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0026 - accuracy: 0.9829 - val_loss: 0.0034 - val_accuracy: 0.9857 - lr: 3.8742e-04
# Epoch 90/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9852
# Epoch 90: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0025 - accuracy: 0.9854 - val_loss: 0.0032 - val_accuracy: 0.9850 - lr: 3.8742e-04
# Epoch 91/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9830
# Epoch 91: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0030 - accuracy: 0.9831 - val_loss: 0.0029 - val_accuracy: 0.9842 - lr: 3.8742e-04
# Epoch 92/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9841
# Epoch 92: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0025 - accuracy: 0.9840 - val_loss: 0.0029 - val_accuracy: 0.9880 - lr: 3.8742e-04
# Epoch 93/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9830
# Epoch 93: val_loss did not improve from 0.00242
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0003486784757114947.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0024 - accuracy: 0.9831 - val_loss: 0.0028 - val_accuracy: 0.9850 - lr: 3.8742e-04
# Epoch 94/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9831
# Epoch 94: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0022 - accuracy: 0.9831 - val_loss: 0.0026 - val_accuracy: 0.9857 - lr: 3.4868e-04
# Epoch 95/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9832
# Epoch 95: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0023 - accuracy: 0.9829 - val_loss: 0.0026 - val_accuracy: 0.9805 - lr: 3.4868e-04
# Epoch 96/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9830
# Epoch 96: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0022 - accuracy: 0.9833 - val_loss: 0.0028 - val_accuracy: 0.9865 - lr: 3.4868e-04
# Epoch 97/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9828
# Epoch 97: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0023 - accuracy: 0.9829 - val_loss: 0.0031 - val_accuracy: 0.9820 - lr: 3.4868e-04
# Epoch 98/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9829
# Epoch 98: val_loss did not improve from 0.00242
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 0.00031381062290165574.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0022 - accuracy: 0.9829 - val_loss: 0.0028 - val_accuracy: 0.9880 - lr: 3.4868e-04
# Epoch 99/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9857
# Epoch 99: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0021 - accuracy: 0.9859 - val_loss: 0.0026 - val_accuracy: 0.9835 - lr: 3.1381e-04
# Epoch 100/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9849
# Epoch 100: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0021 - accuracy: 0.9850 - val_loss: 0.0025 - val_accuracy: 0.9850 - lr: 3.1381e-04
# Epoch 101/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9852
# Epoch 101: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 18ms/step - loss: 0.0021 - accuracy: 0.9852 - val_loss: 0.0026 - val_accuracy: 0.9850 - lr: 3.1381e-04
# Epoch 102/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9841
# Epoch 102: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0019 - accuracy: 0.9842 - val_loss: 0.0026 - val_accuracy: 0.9865 - lr: 3.1381e-04
# Epoch 103/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9849
# Epoch 103: val_loss did not improve from 0.00242
#
# Epoch 103: ReduceLROnPlateau reducing learning rate to 0.0002824295632308349.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0020 - accuracy: 0.9848 - val_loss: 0.0028 - val_accuracy: 0.9887 - lr: 3.1381e-04
# Epoch 104/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9820
# Epoch 104: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0022 - accuracy: 0.9822 - val_loss: 0.0025 - val_accuracy: 0.9917 - lr: 2.8243e-04
# Epoch 105/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9829
# Epoch 105: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0020 - accuracy: 0.9829 - val_loss: 0.0027 - val_accuracy: 0.9835 - lr: 2.8243e-04
# Epoch 106/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9855
# Epoch 106: val_loss did not improve from 0.00242
# 167/167 [==============================] - 3s 19ms/step - loss: 0.0021 - accuracy: 0.9852 - val_loss: 0.0032 - val_accuracy: 0.9887 - lr: 2.8243e-04
# Epoch 107/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9830
# Epoch 107: val_loss improved from 0.00242 to 0.00222, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0020 - accuracy: 0.9831 - val_loss: 0.0022 - val_accuracy: 0.9850 - lr: 2.8243e-04
# Epoch 108/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9848
# Epoch 108: val_loss did not improve from 0.00222
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0019 - accuracy: 0.9848 - val_loss: 0.0026 - val_accuracy: 0.9842 - lr: 2.8243e-04
# Epoch 109/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9848
# Epoch 109: val_loss improved from 0.00222 to 0.00219, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0019 - accuracy: 0.9848 - val_loss: 0.0022 - val_accuracy: 0.9850 - lr: 2.8243e-04
# Epoch 110/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9867
# Epoch 110: val_loss did not improve from 0.00219
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0020 - accuracy: 0.9867 - val_loss: 0.0031 - val_accuracy: 0.9797 - lr: 2.8243e-04
# Epoch 111/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9825
# Epoch 111: val_loss did not improve from 0.00219
# 167/167 [==============================] - 3s 18ms/step - loss: 0.0021 - accuracy: 0.9825 - val_loss: 0.0025 - val_accuracy: 0.9827 - lr: 2.8243e-04
# Epoch 112/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9835
# Epoch 112: val_loss did not improve from 0.00219
#
# Epoch 112: ReduceLROnPlateau reducing learning rate to 0.00025418660952709616.
# 167/167 [==============================] - 3s 18ms/step - loss: 0.0022 - accuracy: 0.9835 - val_loss: 0.0029 - val_accuracy: 0.9820 - lr: 2.8243e-04
# Epoch 113/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9841
# Epoch 113: val_loss did not improve from 0.00219
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0021 - accuracy: 0.9842 - val_loss: 0.0026 - val_accuracy: 0.9790 - lr: 2.5419e-04
# Epoch 114/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9836
# Epoch 114: val_loss did not improve from 0.00219
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0021 - accuracy: 0.9837 - val_loss: 0.0029 - val_accuracy: 0.9857 - lr: 2.5419e-04
# Epoch 115/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9873
# Epoch 115: val_loss did not improve from 0.00219
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0019 - accuracy: 0.9872 - val_loss: 0.0027 - val_accuracy: 0.9842 - lr: 2.5419e-04
# Epoch 116/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9834
# Epoch 116: val_loss did not improve from 0.00219
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0018 - accuracy: 0.9835 - val_loss: 0.0026 - val_accuracy: 0.9827 - lr: 2.5419e-04
# Epoch 117/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9835
# Epoch 117: val_loss did not improve from 0.00219
#
# Epoch 117: ReduceLROnPlateau reducing learning rate to 0.00022876793809700757.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0017 - accuracy: 0.9835 - val_loss: 0.0023 - val_accuracy: 0.9842 - lr: 2.5419e-04
# Epoch 118/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9865
# Epoch 118: val_loss improved from 0.00219 to 0.00209, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0019 - accuracy: 0.9863 - val_loss: 0.0021 - val_accuracy: 0.9835 - lr: 2.2877e-04
# Epoch 119/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9883
# Epoch 119: val_loss did not improve from 0.00209
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0018 - accuracy: 0.9882 - val_loss: 0.0022 - val_accuracy: 0.9812 - lr: 2.2877e-04
# Epoch 120/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9860
# Epoch 120: val_loss improved from 0.00209 to 0.00197, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0017 - accuracy: 0.9861 - val_loss: 0.0020 - val_accuracy: 0.9797 - lr: 2.2877e-04
# Epoch 121/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9867
# Epoch 121: val_loss did not improve from 0.00197
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0017 - accuracy: 0.9867 - val_loss: 0.0023 - val_accuracy: 0.9872 - lr: 2.2877e-04
# Epoch 122/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9857
# Epoch 122: val_loss did not improve from 0.00197
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0017 - accuracy: 0.9855 - val_loss: 0.0022 - val_accuracy: 0.9827 - lr: 2.2877e-04
# Epoch 123/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9885
# Epoch 123: val_loss did not improve from 0.00197
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0018 - accuracy: 0.9884 - val_loss: 0.0022 - val_accuracy: 0.9827 - lr: 2.2877e-04
# Epoch 124/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9841
# Epoch 124: val_loss did not improve from 0.00197
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0021 - accuracy: 0.9842 - val_loss: 0.0023 - val_accuracy: 0.9827 - lr: 2.2877e-04
# Epoch 125/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9867
# Epoch 125: val_loss did not improve from 0.00197
#
# Epoch 125: ReduceLROnPlateau reducing learning rate to 0.00020589114428730683.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0018 - accuracy: 0.9869 - val_loss: 0.0022 - val_accuracy: 0.9842 - lr: 2.2877e-04
# Epoch 126/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9842
# Epoch 126: val_loss improved from 0.00197 to 0.00179, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0018 - accuracy: 0.9844 - val_loss: 0.0018 - val_accuracy: 0.9850 - lr: 2.0589e-04
# Epoch 127/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9837
# Epoch 127: val_loss did not improve from 0.00179
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0017 - accuracy: 0.9835 - val_loss: 0.0020 - val_accuracy: 0.9827 - lr: 2.0589e-04
# Epoch 128/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9877
# Epoch 128: val_loss did not improve from 0.00179
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0017 - accuracy: 0.9874 - val_loss: 0.0022 - val_accuracy: 0.9820 - lr: 2.0589e-04
# Epoch 129/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9878
# Epoch 129: val_loss did not improve from 0.00179
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0018 - accuracy: 0.9876 - val_loss: 0.0025 - val_accuracy: 0.9797 - lr: 2.0589e-04
# Epoch 130/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9837
# Epoch 130: val_loss did not improve from 0.00179
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0017 - accuracy: 0.9837 - val_loss: 0.0027 - val_accuracy: 0.9820 - lr: 2.0589e-04
# Epoch 131/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9862
# Epoch 131: val_loss did not improve from 0.00179
#
# Epoch 131: ReduceLROnPlateau reducing learning rate to 0.00018530203378759326.
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0017 - accuracy: 0.9863 - val_loss: 0.0020 - val_accuracy: 0.9880 - lr: 2.0589e-04
# Epoch 132/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9876
# Epoch 132: val_loss did not improve from 0.00179
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0016 - accuracy: 0.9878 - val_loss: 0.0023 - val_accuracy: 0.9835 - lr: 1.8530e-04
# Epoch 133/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9844
# Epoch 133: val_loss did not improve from 0.00179
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0016 - accuracy: 0.9842 - val_loss: 0.0022 - val_accuracy: 0.9880 - lr: 1.8530e-04
# Epoch 134/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9859
# Epoch 134: val_loss did not improve from 0.00179
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 0.9857 - val_loss: 0.0019 - val_accuracy: 0.9820 - lr: 1.8530e-04
# Epoch 135/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9847
# Epoch 135: val_loss did not improve from 0.00179
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0017 - accuracy: 0.9850 - val_loss: 0.0020 - val_accuracy: 0.9925 - lr: 1.8530e-04
# Epoch 136/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9851
# Epoch 136: val_loss did not improve from 0.00179
#
# Epoch 136: ReduceLROnPlateau reducing learning rate to 0.00016677183302817866.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0017 - accuracy: 0.9854 - val_loss: 0.0020 - val_accuracy: 0.9857 - lr: 1.8530e-04
# Epoch 137/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9856
# Epoch 137: val_loss improved from 0.00179 to 0.00170, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 0.9857 - val_loss: 0.0017 - val_accuracy: 0.9842 - lr: 1.6677e-04
# Epoch 138/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9904
# Epoch 138: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 0.9904 - val_loss: 0.0018 - val_accuracy: 0.9835 - lr: 1.6677e-04
# Epoch 139/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9875
# Epoch 139: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 0.9872 - val_loss: 0.0019 - val_accuracy: 0.9842 - lr: 1.6677e-04
# Epoch 140/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9846
# Epoch 140: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 18ms/step - loss: 0.0016 - accuracy: 0.9844 - val_loss: 0.0021 - val_accuracy: 0.9857 - lr: 1.6677e-04
# Epoch 141/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9869
# Epoch 141: val_loss did not improve from 0.00170
#
# Epoch 141: ReduceLROnPlateau reducing learning rate to 0.00015009464841568844.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 0.9870 - val_loss: 0.0022 - val_accuracy: 0.9827 - lr: 1.6677e-04
# Epoch 142/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9885
# Epoch 142: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 0.9884 - val_loss: 0.0019 - val_accuracy: 0.9865 - lr: 1.5009e-04
# Epoch 143/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9861
# Epoch 143: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0015 - accuracy: 0.9861 - val_loss: 0.0018 - val_accuracy: 0.9820 - lr: 1.5009e-04
# Epoch 144/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9833
# Epoch 144: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 0.9833 - val_loss: 0.0020 - val_accuracy: 0.9842 - lr: 1.5009e-04
# Epoch 145/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9869
# Epoch 145: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 0.9869 - val_loss: 0.0020 - val_accuracy: 0.9850 - lr: 1.5009e-04
# Epoch 146/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9855
# Epoch 146: val_loss did not improve from 0.00170
#
# Epoch 146: ReduceLROnPlateau reducing learning rate to 0.0001350851875031367.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 0.9857 - val_loss: 0.0020 - val_accuracy: 0.9895 - lr: 1.5009e-04
# Epoch 147/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9860
# Epoch 147: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0015 - accuracy: 0.9861 - val_loss: 0.0019 - val_accuracy: 0.9835 - lr: 1.3509e-04
# Epoch 148/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9866
# Epoch 148: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0018 - accuracy: 0.9865 - val_loss: 0.0025 - val_accuracy: 0.9872 - lr: 1.3509e-04
# Epoch 149/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9861
# Epoch 149: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 0.9861 - val_loss: 0.0023 - val_accuracy: 0.9842 - lr: 1.3509e-04
# Epoch 150/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9850
# Epoch 150: val_loss did not improve from 0.00170
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0017 - accuracy: 0.9850 - val_loss: 0.0018 - val_accuracy: 0.9835 - lr: 1.3509e-04
# Epoch 151/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9870
# Epoch 151: val_loss did not improve from 0.00170
#
# Epoch 151: ReduceLROnPlateau reducing learning rate to 0.00012157666351413355.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0015 - accuracy: 0.9870 - val_loss: 0.0020 - val_accuracy: 0.9887 - lr: 1.3509e-04
# Epoch 152/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9855
# Epoch 152: val_loss did not improve from 0.00170
# ...
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0014 - accuracy: 0.9869 - val_loss: 0.0018 - val_accuracy: 0.9850 - lr: 7.1790e-05
# Epoch 182/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9882
# Epoch 182: val_loss did not improve from 0.00164
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0014 - accuracy: 0.9882 - val_loss: 0.0017 - val_accuracy: 0.9857 - lr: 7.1790e-05
# Epoch 183/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9881
# Epoch 183: val_loss did not improve from 0.00164
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9878 - val_loss: 0.0018 - val_accuracy: 0.9850 - lr: 7.1790e-05
# Epoch 184/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9861
# Epoch 184: val_loss did not improve from 0.00164
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0014 - accuracy: 0.9861 - val_loss: 0.0018 - val_accuracy: 0.9820 - lr: 7.1790e-05
# Epoch 185/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9889
# Epoch 185: val_loss did not improve from 0.00164
#
# Epoch 185: ReduceLROnPlateau reducing learning rate to 6.461082011810504e-05.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9889 - val_loss: 0.0018 - val_accuracy: 0.9865 - lr: 7.1790e-05
# Epoch 186/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9875
# Epoch 186: val_loss did not improve from 0.00164
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9876 - val_loss: 0.0017 - val_accuracy: 0.9850 - lr: 6.4611e-05
# Epoch 187/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9893
# Epoch 187: val_loss did not improve from 0.00164
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9893 - val_loss: 0.0017 - val_accuracy: 0.9865 - lr: 6.4611e-05
# Epoch 188/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9882
# Epoch 188: val_loss did not improve from 0.00164
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9882 - val_loss: 0.0018 - val_accuracy: 0.9872 - lr: 6.4611e-05
# Epoch 189/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9865
# Epoch 189: val_loss improved from 0.00164 to 0.00157, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0013 - accuracy: 0.9865 - val_loss: 0.0016 - val_accuracy: 0.9850 - lr: 6.4611e-05
# Epoch 190/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9891
# Epoch 190: val_loss did not improve from 0.00157
#
# Epoch 190: ReduceLROnPlateau reducing learning rate to 5.8149741380475466e-05.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9891 - val_loss: 0.0016 - val_accuracy: 0.9857 - lr: 6.4611e-05
# Epoch 191/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9889
# Epoch 191: val_loss did not improve from 0.00157
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9889 - val_loss: 0.0016 - val_accuracy: 0.9902 - lr: 5.8150e-05
# Epoch 192/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9889
# Epoch 192: val_loss did not improve from 0.00157
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9889 - val_loss: 0.0017 - val_accuracy: 0.9857 - lr: 5.8150e-05
# Epoch 193/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9863
# Epoch 193: val_loss did not improve from 0.00157
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9863 - val_loss: 0.0019 - val_accuracy: 0.9857 - lr: 5.8150e-05
# Epoch 194/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9874
# Epoch 194: val_loss did not improve from 0.00157
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9870 - val_loss: 0.0019 - val_accuracy: 0.9872 - lr: 5.8150e-05
# Epoch 195/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9888
# Epoch 195: val_loss did not improve from 0.00157
#
# Epoch 195: ReduceLROnPlateau reducing learning rate to 5.233476658759173e-05.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9884 - val_loss: 0.0017 - val_accuracy: 0.9850 - lr: 5.8150e-05
# Epoch 196/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9866
# Epoch 196: val_loss did not improve from 0.00157
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9867 - val_loss: 0.0018 - val_accuracy: 0.9850 - lr: 5.2335e-05
# Epoch 197/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9850
# Epoch 197: val_loss did not improve from 0.00157
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9850 - val_loss: 0.0019 - val_accuracy: 0.9835 - lr: 5.2335e-05
# Epoch 198/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9891
# Epoch 198: val_loss did not improve from 0.00157
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9891 - val_loss: 0.0019 - val_accuracy: 0.9872 - lr: 5.2335e-05
# Epoch 199/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9885
# Epoch 199: val_loss did not improve from 0.00157
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9886 - val_loss: 0.0017 - val_accuracy: 0.9865 - lr: 5.2335e-05
# Epoch 200/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9895
# Epoch 200: val_loss did not improve from 0.00157
#
# Epoch 200: ReduceLROnPlateau reducing learning rate to 4.7101289601414466e-05.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9895 - val_loss: 0.0016 - val_accuracy: 0.9865 - lr: 5.2335e-05
# Epoch 201/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9887
# Epoch 201: val_loss improved from 0.00157 to 0.00155, saving model to ana-cont_1200_s2_best.h5
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9887 - val_loss: 0.0016 - val_accuracy: 0.9850 - lr: 4.7101e-05
# Epoch 202/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9870
# Epoch 202: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9870 - val_loss: 0.0016 - val_accuracy: 0.9835 - lr: 4.7101e-05
# Epoch 203/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9861
# Epoch 203: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9863 - val_loss: 0.0018 - val_accuracy: 0.9857 - lr: 4.7101e-05
# Epoch 204/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9868
# Epoch 204: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9870 - val_loss: 0.0017 - val_accuracy: 0.9865 - lr: 4.7101e-05
# Epoch 205/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9876
# Epoch 205: val_loss did not improve from 0.00155
#
# Epoch 205: ReduceLROnPlateau reducing learning rate to 4.239116096869111e-05.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9874 - val_loss: 0.0018 - val_accuracy: 0.9917 - lr: 4.7101e-05
# Epoch 206/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9893
# Epoch 206: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9895 - val_loss: 0.0017 - val_accuracy: 0.9902 - lr: 4.2391e-05
# Epoch 207/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9891
# Epoch 207: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9891 - val_loss: 0.0018 - val_accuracy: 0.9865 - lr: 4.2391e-05
# Epoch 208/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9859
# Epoch 208: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9861 - val_loss: 0.0016 - val_accuracy: 0.9842 - lr: 4.2391e-05
# Epoch 209/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9874
# Epoch 209: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0013 - accuracy: 0.9874 - val_loss: 0.0016 - val_accuracy: 0.9857 - lr: 4.2391e-05
# Epoch 210/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9894
# Epoch 210: val_loss did not improve from 0.00155
#
# Epoch 210: ReduceLROnPlateau reducing learning rate to 3.815204618149437e-05.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9891 - val_loss: 0.0017 - val_accuracy: 0.9865 - lr: 4.2391e-05
# Epoch 211/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9866
# Epoch 211: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9861 - val_loss: 0.0017 - val_accuracy: 0.9850 - lr: 3.8152e-05
# Epoch 212/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9891
# Epoch 212: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9893 - val_loss: 0.0018 - val_accuracy: 0.9842 - lr: 3.8152e-05
# Epoch 213/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9919
# Epoch 213: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9919 - val_loss: 0.0017 - val_accuracy: 0.9827 - lr: 3.8152e-05
# Epoch 214/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9885
# Epoch 214: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9886 - val_loss: 0.0017 - val_accuracy: 0.9880 - lr: 3.8152e-05
# Epoch 215/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9868
# Epoch 215: val_loss did not improve from 0.00155
#
# Epoch 215: ReduceLROnPlateau reducing learning rate to 3.4336842873017304e-05.
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0013 - accuracy: 0.9867 - val_loss: 0.0016 - val_accuracy: 0.9850 - lr: 3.8152e-05
# Epoch 216/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9887
# Epoch 216: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0013 - accuracy: 0.9887 - val_loss: 0.0017 - val_accuracy: 0.9850 - lr: 3.4337e-05
# Epoch 217/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9893
# Epoch 217: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9895 - val_loss: 0.0017 - val_accuracy: 0.9850 - lr: 3.4337e-05
# Epoch 218/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9890
# Epoch 218: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0012 - accuracy: 0.9889 - val_loss: 0.0016 - val_accuracy: 0.9850 - lr: 3.4337e-05
# Epoch 219/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9903
# Epoch 219: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0013 - accuracy: 0.9904 - val_loss: 0.0016 - val_accuracy: 0.9865 - lr: 3.4337e-05
# Epoch 220/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9889
# Epoch 220: val_loss did not improve from 0.00155
#
# Epoch 220: ReduceLROnPlateau reducing learning rate to 3.0903160222806036e-05.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9889 - val_loss: 0.0016 - val_accuracy: 0.9872 - lr: 3.4337e-05
# Epoch 221/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9878
# Epoch 221: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9878 - val_loss: 0.0017 - val_accuracy: 0.9850 - lr: 3.0903e-05
# Epoch 222/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9890
# Epoch 222: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9889 - val_loss: 0.0017 - val_accuracy: 0.9865 - lr: 3.0903e-05
# Epoch 223/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9877
# Epoch 223: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9878 - val_loss: 0.0017 - val_accuracy: 0.9842 - lr: 3.0903e-05
# Epoch 224/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9881
# Epoch 224: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9884 - val_loss: 0.0017 - val_accuracy: 0.9857 - lr: 3.0903e-05
# Epoch 225/400
# 167/167 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9880
# Epoch 225: val_loss did not improve from 0.00155
#
# Epoch 225: ReduceLROnPlateau reducing learning rate to 2.7812844200525434e-05.
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0012 - accuracy: 0.9880 - val_loss: 0.0017 - val_accuracy: 0.9857 - lr: 3.0903e-05
# Epoch 226/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9887
# Epoch 226: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9887 - val_loss: 0.0018 - val_accuracy: 0.9865 - lr: 2.7813e-05
# Epoch 227/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9872
# Epoch 227: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9874 - val_loss: 0.0017 - val_accuracy: 0.9865 - lr: 2.7813e-05
# Epoch 228/400
# 164/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9889
# Epoch 228: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0013 - accuracy: 0.9889 - val_loss: 0.0016 - val_accuracy: 0.9850 - lr: 2.7813e-05
# Epoch 229/400
# 166/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9875
# Epoch 229: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9876 - val_loss: 0.0017 - val_accuracy: 0.9842 - lr: 2.7813e-05
# Epoch 230/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9869
# Epoch 230: val_loss did not improve from 0.00155
#
# Epoch 230: ReduceLROnPlateau reducing learning rate to 2.5031560107890984e-05.
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 0.9867 - val_loss: 0.0017 - val_accuracy: 0.9850 - lr: 2.7813e-05
# Epoch 231/400
# 165/167 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9873Restoring model weights from the end of the best epoch: 201.
#
# Epoch 231: val_loss did not improve from 0.00155
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 0.9874 - val_loss: 0.0017 - val_accuracy: 0.9850 - lr: 2.5032e-05
# Epoch 231: early stopping

# %% [markdown]
# ### Learing result
#
# * Visualization of the training and validation results
# * Validation should not much over train validation, because of the augmentation of train data (validation data not)
# * Beware, the best model will be used. This can be from an earlier epoch as the last. (mostly the last -30)

# %%
loss_ges = np.append(loss_ges, history.history['loss'])

if (Training_Percentage > 0):
    val_loss_ges = np.append(val_loss_ges, history.history['val_loss'])
    plt.semilogy(val_loss_ges)

plt.semilogy(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['eval','train'], loc='upper left')
plt.show()

# %% [markdown]
# ### Check the model by data
#
# * The following code uses the trained model to check the deviation for each picture (train + validation).
# * The max_delta can be used to get the accuracy with allowed differences (for instance +/- 0.1)
# * The first (max) 49 false predicted images will be shown
# * a csv-file with all false predicted images will be created. It can be used for relabeling. Usage `python3 -m collectmeteranalog  --labelfile=ana-class100_s1_false_predicted.csv --model=ana-class100_s1q.tflite` (see https://github.com/haverland/collectmeteranalog)

# %%
import numpy as np
from tensorflow import keras
import pandas as pd

max_delta=0.11

def plot_dataset(images, labels, columns=10, rows=5, figsize=(18, 10)):

    fig = plt.figure(figsize=figsize)
    
    for i in range(1, columns*rows +1):
        if (i>len(labels)):
            break
        fig.add_subplot(rows, columns, i)
        plt.title(labels[i-1])  # set title
        plt.imshow((images[i-1]).astype(np.uint8), aspect='1', extent=[0, 1, 0, 1])
        # yellow lines
        ax=plt.gca()
        ax.get_yaxis().set_visible(False) 
        ax.get_xaxis().set_visible(False) 
        
        plt.tight_layout()
    plt.show()

def plot_divergence(divergationset, title1, nb_classes):
    fig = plt.figure(figsize=(40, 10))
    fig.suptitle(title1)
    plt.bar(np.arange (0, nb_classes/10, 0.1), divergationset, width=0.09, align='center')
    plt.ylabel('count')
    plt.xlabel('digit class')
    plt.xticks(np.arange(0, nb_classes/10, 0.1))
    return fig

model = keras.models.load_model(TFliteNamingAndVersion + "_best.h5")

classes = model.predict(x_data.astype(np.float32))
predictions = np.empty(len(classes))
for i, output in enumerate(classes):
    predictions[i] =  ((np.arctan2(output[0], output[1])/(2*np.pi)) % 1)*10
#predictions = np.arctan2(classes[0], out_cos[1])/(2*math.pi)) % 1)*10
#predictions = np.argmax(classes, axis=1).reshape(-1)/10

# 9.9 <> 0 = 0.1 and 1.1 <> 1.2 = 0.1
differences = np.minimum(np.abs(predictions-y_data), np.abs(predictions-(10-y_data)))
# used for filtering
false_differences = differences>max_delta
# only differences bigger than delta. so small differences can be ignored in early stages
false_predicted = differences[false_differences]
false_images = x_data[false_differences]
false_labels = [ "Expected: " + str(y1) + "\n Predicted: " + "{:.1f}".format(p) + "\n" + str(f)[-26:-4] for y1, p, f in zip(y_data[false_differences], predictions[false_differences], f_data[false_differences])]
false_files = [ f for f in  f_data[false_differences]]

print(f"Tested images: {len(y_data)}. {len(false_predicted)} false predicted. Accuracy is: {1-len(false_predicted)/len(y_data)}")
# plot the differences (max difference can only be 5.0)
plot_divergence(np.bincount(np.array(np.round(false_predicted*10)).astype(int), minlength=51), "Divergation of false predicted", 51)

# plot the false predicted images
plot_dataset(np.array(false_images), false_labels, columns=7, rows=7, figsize=(18,18))
#print(false_files)
fpf = pd.DataFrame(false_files)

# the csv can be used with collectmeterdigits to fix labels
# python3 -m collectmeteranalog  --labelfile=ana-class100_s1_false_predicted.csv --model=ana-class100_s1q.tflite
fpf.to_csv(TFliteNamingAndVersion + '_false_predicted.csv')
# Out:
#  33/209 [===>..........................] - ETA: 0s
# 2023-03-24 00:16:25.712774: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 209/209 [==============================] - 1s 3ms/step
# Tested images: 6661. 526 false predicted. Accuracy is: 0.9210328779462543

# %% [markdown]
# ### Save the model
#
# * Save the model to the file with the "tflite" file format
# * quantize the model and store it as -q.tflite

# %%
FileName = TFliteNamingAndVersion

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open(FileName + ".tflite", "wb").write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpalizq9ay/assets
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpalizq9ay/assets
# 2023-03-24 00:15:52.870068: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2023-03-24 00:15:52.870085: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2023-03-24 00:15:52.870501: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpalizq9ay
# 2023-03-24 00:15:52.872627: I tensorflow/cc/saved_model/reader.cc:81] Reading meta graph with tags { serve }
# 2023-03-24 00:15:52.872633: I tensorflow/cc/saved_model/reader.cc:122] Reading SavedModel debug info (if present) from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpalizq9ay
# 2023-03-24 00:15:52.878534: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2023-03-24 00:15:52.880409: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2023-03-24 00:15:52.946362: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpalizq9ay
# 2023-03-24 00:15:52.967621: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 97121 microseconds.
# 2023-03-24 00:15:52.996423: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:263] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 186112

# %%
from pathlib import Path
import tensorflow as tf

FileName = TFliteNamingAndVersion + "_q" + ".tflite"

def representative_dataset():
    for n in range(x_data[0].size):
      data = np.expand_dims(x_data[n], axis=0)
      yield [data.astype(np.float32)]
        
converter2 = tf.lite.TFLiteConverter.from_keras_model(model)
converter2.representative_dataset = representative_dataset
converter2.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter2.convert()

open(FileName, "wb").write(tflite_quant_model)
print(FileName)
Path(FileName).stat().st_size
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpqbf4lqfj/assets
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpqbf4lqfj/assets
# /opt/homebrew/Caskroom/miniforge/base/envs/mlp2/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# ana-cont_1200_s2_q.tflite
# 2023-03-24 00:15:57.021117: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2023-03-24 00:15:57.021132: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2023-03-24 00:15:57.021212: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpqbf4lqfj
# 2023-03-24 00:15:57.023214: I tensorflow/cc/saved_model/reader.cc:81] Reading meta graph with tags { serve }
# 2023-03-24 00:15:57.023220: I tensorflow/cc/saved_model/reader.cc:122] Reading SavedModel debug info (if present) from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpqbf4lqfj
# 2023-03-24 00:15:57.030532: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2023-03-24 00:15:57.096312: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpqbf4lqfj
# 2023-03-24 00:15:57.117174: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 95963 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: 0, output_inference_type: 0
# 55624
