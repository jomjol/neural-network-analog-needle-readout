# %% [markdown]
# # CNN Training
#
# Target of this code is to train a CNN network to extract the needle position of an analog needle device.
#
# ### Preparing the training
# * First all libraries are loaded
#     * It is assumed, that they are installed during the Python setup
# * matplotlib is set to print the output inline in the jupyter notebook

# %%
########### Basic Parameters for Running: ################################
    
TFliteNamingAndVersion = "ana-class100_0172_s2"   # Used for tflite Filename
Training_Percentage = 0.2              # 0.0 = Use all Images for Training
Batch_Size = 32
Epoch_Anz = 400
input_shape = (32,32,3)

##########################################################################



from absl import app as absl_app
from absl import flags
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import numpy as np
from sklearn.utils import shuffle
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Conv2D, MaxPool2D, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import History 
import math
from PIL import Image 

FileName = TFliteNamingAndVersion + "_qs" + ".tflite"


loss_ges = np.array([])
val_loss_ges = np.array([])

# %matplotlib inline
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load training data
# * The data is expected in the "Input_dir"
# * Picture size must be 32x32 with 3 color channels (RGB)
# * The filename contains the informations needed for training in the first 3 digits::
# * Typical filename:
#     * x.y-zzzz.jpg
#     * e.g. "4.6_Lfd-1406_zeiger3_2019-06-02T050011"
#
# |Place holder | Meaning                     | Usage        |
# |------------- |-----------------------------|--------------|
# | **x.y**          | readout value               | **to be learned** |
# | zzzz        | additional information              | not needed   |
#
# * The images are stored in the x_data[]
# * The expected output for each image in the corresponding y_data[]
#     * The periodic nature is reflected in a **sin/cos coding**, which allows to restore the angle/counter value with an arctan later on.
#
# * The last step is a shuffle (from sklearn.utils) as the filenames are on order due to the encoding of the expected analog readout in the filename

# %%
Input_dir='data_resize_all'

files = glob.glob("data_raw_all" + '/*.jpg')
y_data = np.empty((len(files)))
f_data = np.empty((len(files)), dtype="<U250")
x_data = np.empty((len(files),input_shape[0],input_shape[1],input_shape[2]))

for i, aktfile in enumerate(files):
    base = os.path.basename(aktfile)

    # get label from filename (1.2_ new or 1_ old),
    if (base[1]=="."):
        target = base[0:3]
    else:
        target = base[0:1]
    category = float(target)
    
    test_image = Image.open(aktfile).resize((input_shape[0],input_shape[1]), Image.Resampling.NEAREST)
    test_image = np.array(test_image, dtype="float32")
    f_data[i] =  aktfile
    x_data[i] = test_image
    y_data[i] =  category
print("Analog data count: ", len(y_data))  

#x_data = np.array(x_data).astype(np.floa<t32)
#y_data = np.array(y_data)
#y_data = np.expand_dims(y_data, -1)#.astype(np.int8)
print(x_data.shape)

x_data, y_data, f_data = shuffle(x_data, y_data, f_data)
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)
y_train = keras.utils.to_categorical(y_train*10, 100)
y_test = keras.utils.to_categorical(y_test*10, 100)

print(np.expand_dims(y_data, axis=1).shape)
# Out:
# Analog data count:  1739
# (1739, 32, 32, 3)
# (1739, 1)

# %% [markdown]
# ### Distribution of the data
#
# Uneven distribution of data can lead to poorer results.
#
# In some classes (8.4) we have only 20 images. In other classes over 100 images.

# %%
_, inverse = np.unique(y_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
fig = plt.figure(figsize=(40, 10))
fig.suptitle("Distribution of data")
plt.bar(np.arange (0, 100/10, 0.1), ziffer_bincount, width=0.09, align='center')
plt.ylabel('count')
plt.xlabel('digit class')
plt.tight_layout()
_ = plt.xticks(np.arange(0, 100/10, 0.1))

# %% [markdown]
# ### Define the model
#
# The layout of the network ist a typcial CNN network with alternating 2x **Conv2D**, **BatchNormalization** and **MaxPool2D** layers. Finished after **flattening** with additional **Dense** layer.
#
# **Dropout** between CNN layers are 0.2, between fully connected layers 0.4, but only the fully connected output layer.
#
# * Shape of the input layer: (32, 32, 3)
# * Shape of the output layer: (100) - classification 0.0 ... 9.9

# %%
inputs = tf.keras.Input(shape=(32, 32, 3))
x = tf.keras.layers.BatchNormalization()(inputs)

x = tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation="relu")(x)
#x = tf.keras.layers.BatchNormalization()(x)
#x = tf.keras.layers.Conv2D(32, (1, 1), padding='same', activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.MaxPool2D(pool_size=(4,4))(x)
x = tf.keras.layers.Dropout(0.15)(x)

x = tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.15)(x)
x = tf.keras.layers.Conv2D(48, (3, 3), padding='same', activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.MaxPool2D(pool_size=(4,4))(x)
x = tf.keras.layers.Dropout(0.15)(x)

x = tf.keras.layers.Conv2D(48, (3, 3), padding='same', activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.15)(x)
x = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.MaxPool2D(pool_size=(2,2))(x)
x = tf.keras.layers.Dropout(0.15)(x)

x = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
#x = tf.keras.layers.MaxPool2D(pool_size=(2,2))(x)
#
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dropout(0.3)(x)
output = tf.keras.layers.Dense(100)(x)

model = tf.keras.Model(inputs=inputs, outputs=output)


model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), optimizer=tf.keras.optimizers.legacy.Adam(
    learning_rate=1e-3), metrics = ["accuracy"])
model.summary()
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2024-04-08 19:42:42.762611: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-08 19:42:42.762653: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  batch_normalization (Batch  (None, 32, 32, 3)         12
#  Normalization)
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        2432
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 32)          0
#  D)
#
#  dropout (Dropout)           (None, 8, 8, 32)          0
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 32)          9248
#
#  batch_normalization_2 (Bat  (None, 8, 8, 32)          128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 8, 8, 32)          0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 48)          13872
#
#  batch_normalization_3 (Bat  (None, 8, 8, 48)          192
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 2, 2, 48)          0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 48)          0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 48)          20784
#
#  batch_normalization_4 (Bat  (None, 2, 2, 48)          192
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 2, 2, 48)          0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 64)          27712
#
#  batch_normalization_5 (Bat  (None, 2, 2, 64)          256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 1, 1, 64)          0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 1, 1, 64)          0
#
#  conv2d_5 (Conv2D)           (None, 1, 1, 64)          36928
#
#  batch_normalization_6 (Bat  (None, 1, 1, 64)          256
#  chNormalization)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 100)               6500
#
# =================================================================
# Total params: 118640 (463.44 KB)
# Trainable params: 118058 (461.16 KB)
# Non-trainable params: 582 (2.27 KB)
# _________________________________________________________________

# %% [markdown]
# # Training
# The input pictures are randomly scattered for brightness and pixel shift variations. These is implemented with a ImageDataGenerator.
#
#
# The training is in one step.
#
# The best model will be stored as \<modelname\>_best.h5

# %% [markdown]
# ### Augmentation
#
# Augmentation uses shift, zoom, brightness, shear

# %%
from numpy import pi
import random

Shift_Range = 1/32
Zoom_Range = 0.05
Brightness_Range = 0.3
ShearRange= 3
Rotation_Range=2

def add_noise(img):
    '''Add random noise to an image'''
    VARIABILITY = 3
    deviation = VARIABILITY*random.random()
    noise = np.random.normal(0, deviation, img.shape)
    img += noise
    np.clip(img, 0., 255.)
    return img

datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
                height_shift_range=[-Shift_Range,Shift_Range],
                brightness_range=[1-Brightness_Range,1+Brightness_Range],
                zoom_range=Zoom_Range,
                shear_range=ShearRange,
                rotation_range=Rotation_Range,
                #preprocessing_function=add_noise
                #rescale=1/255
                )
datagen_val = ImageDataGenerator()
train_iterator = datagen.flow(X_train, y_train, batch_size=Batch_Size)
validation_iterator = datagen_val.flow(X_test, y_test, batch_size=Batch_Size)


columns=4
rows=3

fig = plt.figure(figsize=(18, 11))
for i in range(1, columns*rows +1):
    img, label = train_iterator.next()
    ax0 = fig.add_subplot(rows, columns, i)
    target = (np.argmax(label[0])/10)
    plt.title("{:10.1f}\n".format(target))  # set title
    plt.imshow(img[0].astype(np.uint8))
    plt.axis('off')
    ax=plt.gca()
    ax.get_xaxis().set_visible(False) 
    ax2 = fig.add_subplot(rows, columns, i, polar=True, label="polar")
    ax2.set_facecolor("None")
    # suppress the radial labels
    plt.setp(ax.get_yticklabels(), visible=False)

    # set the circumference labels
    ax2.set_xticks(np.linspace(0, 2*pi, 10, endpoint=False))
    ax2.set_xticklabels(range(10))
    ax2.yaxis.grid(False)
    
    # make the labels go clockwise
    ax2.set_theta_direction(-1)
    # place 0 at the top
    ax2.set_theta_offset(pi/2.0)    
    ax2.set_yticklabels([])


    # plt.grid('off')

    # put the points on the circumference
    plt.ylim(0,1)
plt.show()

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau
earlystop = EarlyStopping(monitor='val_loss', mode='min' , patience=30, verbose=1,  restore_best_weights=True)
mc = ModelCheckpoint(TFliteNamingAndVersion + '_best.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True, initial_value_threshold=.9)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=5, min_lr=1e-5, verbose=1)
history = model.fit(train_iterator, 
            validation_data=validation_iterator, 
            batch_size=Batch_Size, 
            epochs = Epoch_Anz,
            callbacks=[earlystop, mc, reduce_lr],
            verbose=1)
# Out:
# Epoch 1/400
# 2024-04-08 19:42:45.583742: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<32x8x8x32xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<32x8x8x32xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<32x2x2x48xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<32x2x2x48xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<32x1x1x64xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<1x32x1x64xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<1x32x1x64xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<32x1x1x64xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<32x2x2x48xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<32x2x2x48xi1>'
#  3/44 [=>............................] - ETA: 1s - loss: 5.2660 - accuracy: 0.0000e+00
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<32x8x8x32xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<32x8x8x32xi1>'
# 21/44 [=============>................] - ETA: 0s - loss: 5.0358 - accuracy: 0.0045
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<15x8x8x32xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<15x8x8x32xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<15x2x2x48xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<15x2x2x48xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<15x1x1x64xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<1x15x1x64xi1>'
# 23/44 [==============>...............] - ETA: 1s - loss: 5.0293 - accuracy: 0.0042
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<1x15x1x64xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<15x1x1x64xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<15x2x2x48xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<15x2x2x48xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<15x8x8x32xi1>'
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.gain_offset_control' op result #0 must be 4D/5D memref of 16-bit float or 8-bit signed integer or 8-bit unsigned integer values, but got 'memref<15x8x8x32xi1>'
# 43/44 [============================>.] - ETA: 0s - loss: 5.0202 - accuracy: 0.0037
# 2024-04-08 19:42:48.285765: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss did not improve from 0.90000
# 44/44 [==============================] - 4s 53ms/step - loss: 5.0201 - accuracy: 0.0036 - val_loss: 4.6074 - val_accuracy: 0.0115 - lr: 0.0010
# Epoch 2/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.8364 - accuracy: 0.0162
# Epoch 2: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 34ms/step - loss: 4.8375 - accuracy: 0.0158 - val_loss: 4.6119 - val_accuracy: 0.0144 - lr: 0.0010
# Epoch 3/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.8035 - accuracy: 0.0118
# Epoch 3: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 4.8049 - accuracy: 0.0115 - val_loss: 4.6136 - val_accuracy: 0.0172 - lr: 0.0010
# Epoch 4/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.7309 - accuracy: 0.0167
# Epoch 4: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 4.7308 - accuracy: 0.0165 - val_loss: 4.6220 - val_accuracy: 0.0144 - lr: 0.0010
# Epoch 5/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.6798 - accuracy: 0.0177
# Epoch 5: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 4.6828 - accuracy: 0.0173 - val_loss: 4.6327 - val_accuracy: 0.0057 - lr: 0.0010
# Epoch 6/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.6280 - accuracy: 0.0228
# Epoch 6: val_loss did not improve from 0.90000
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
# 44/44 [==============================] - 1s 32ms/step - loss: 4.6278 - accuracy: 0.0230 - val_loss: 4.6144 - val_accuracy: 0.0259 - lr: 0.0010
# Epoch 7/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.6322 - accuracy: 0.0147
# Epoch 7: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 34ms/step - loss: 4.6326 - accuracy: 0.0144 - val_loss: 4.6017 - val_accuracy: 0.0201 - lr: 9.0000e-04
# Epoch 8/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.5980 - accuracy: 0.0155
# Epoch 8: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 34ms/step - loss: 4.6008 - accuracy: 0.0151 - val_loss: 4.5834 - val_accuracy: 0.0316 - lr: 9.0000e-04
# Epoch 9/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.5045 - accuracy: 0.0258
# Epoch 9: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 4.5020 - accuracy: 0.0266 - val_loss: 4.5356 - val_accuracy: 0.0316 - lr: 9.0000e-04
# Epoch 10/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.4691 - accuracy: 0.0361
# Epoch 10: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 4.4659 - accuracy: 0.0352 - val_loss: 4.4686 - val_accuracy: 0.0287 - lr: 9.0000e-04
# Epoch 11/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.3407 - accuracy: 0.0464
# Epoch 11: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 4.3410 - accuracy: 0.0467 - val_loss: 4.3632 - val_accuracy: 0.0374 - lr: 9.0000e-04
# Epoch 12/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.1961 - accuracy: 0.0589
# Epoch 12: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 4.1989 - accuracy: 0.0582 - val_loss: 4.1904 - val_accuracy: 0.0431 - lr: 9.0000e-04
# Epoch 13/400
# 43/44 [============================>.] - ETA: 0s - loss: 4.0725 - accuracy: 0.0581
# Epoch 13: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 4.0708 - accuracy: 0.0590 - val_loss: 4.1310 - val_accuracy: 0.0402 - lr: 9.0000e-04
# Epoch 14/400
# 43/44 [============================>.] - ETA: 0s - loss: 3.9551 - accuracy: 0.0721
# Epoch 14: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 3.9543 - accuracy: 0.0719 - val_loss: 3.9312 - val_accuracy: 0.0632 - lr: 9.0000e-04
# Epoch 15/400
# 43/44 [============================>.] - ETA: 0s - loss: 3.8295 - accuracy: 0.0868
# Epoch 15: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 3.8321 - accuracy: 0.0863 - val_loss: 3.7494 - val_accuracy: 0.0632 - lr: 9.0000e-04
# Epoch 16/400
# 43/44 [============================>.] - ETA: 0s - loss: 3.6884 - accuracy: 0.1089
# Epoch 16: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 3.6883 - accuracy: 0.1086 - val_loss: 3.6509 - val_accuracy: 0.0977 - lr: 9.0000e-04
# Epoch 17/400
# 43/44 [============================>.] - ETA: 0s - loss: 3.5898 - accuracy: 0.1001
# Epoch 17: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 34ms/step - loss: 3.5913 - accuracy: 0.1014 - val_loss: 3.4700 - val_accuracy: 0.1092 - lr: 9.0000e-04
# Epoch 18/400
# 43/44 [============================>.] - ETA: 0s - loss: 3.5194 - accuracy: 0.1082
# Epoch 18: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 35ms/step - loss: 3.5167 - accuracy: 0.1064 - val_loss: 3.3991 - val_accuracy: 0.1121 - lr: 9.0000e-04
# Epoch 19/400
# 43/44 [============================>.] - ETA: 0s - loss: 3.3674 - accuracy: 0.1266
# Epoch 19: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 35ms/step - loss: 3.3610 - accuracy: 0.1272 - val_loss: 3.3191 - val_accuracy: 0.1207 - lr: 9.0000e-04
# Epoch 20/400
# 43/44 [============================>.] - ETA: 0s - loss: 3.2266 - accuracy: 0.1420
# Epoch 20: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 36ms/step - loss: 3.2275 - accuracy: 0.1438 - val_loss: 3.1046 - val_accuracy: 0.1293 - lr: 9.0000e-04
# Epoch 21/400
# 43/44 [============================>.] - ETA: 0s - loss: 3.1190 - accuracy: 0.1479
# Epoch 21: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 3.1160 - accuracy: 0.1481 - val_loss: 3.0329 - val_accuracy: 0.1523 - lr: 9.0000e-04
# Epoch 22/400
# 43/44 [============================>.] - ETA: 0s - loss: 3.0364 - accuracy: 0.1553
# Epoch 22: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 3.0408 - accuracy: 0.1538 - val_loss: 2.9124 - val_accuracy: 0.1839 - lr: 9.0000e-04
# Epoch 23/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.9621 - accuracy: 0.1567
# Epoch 23: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 34ms/step - loss: 2.9615 - accuracy: 0.1589 - val_loss: 3.0445 - val_accuracy: 0.1494 - lr: 9.0000e-04
# Epoch 24/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.8712 - accuracy: 0.1751
# Epoch 24: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 35ms/step - loss: 2.8703 - accuracy: 0.1740 - val_loss: 2.7215 - val_accuracy: 0.1810 - lr: 9.0000e-04
# Epoch 25/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.7345 - accuracy: 0.2016
# Epoch 25: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 2.7349 - accuracy: 0.2020 - val_loss: 2.6456 - val_accuracy: 0.1983 - lr: 9.0000e-04
# Epoch 26/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.6935 - accuracy: 0.1950
# Epoch 26: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 2.6918 - accuracy: 0.1955 - val_loss: 2.5384 - val_accuracy: 0.2184 - lr: 9.0000e-04
# Epoch 27/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.6007 - accuracy: 0.2090
# Epoch 27: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.6052 - accuracy: 0.2070 - val_loss: 2.5148 - val_accuracy: 0.2328 - lr: 9.0000e-04
# Epoch 28/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.5458 - accuracy: 0.2134
# Epoch 28: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 2.5510 - accuracy: 0.2114 - val_loss: 2.4652 - val_accuracy: 0.1983 - lr: 9.0000e-04
# Epoch 29/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.4790 - accuracy: 0.2325
# Epoch 29: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 2.4776 - accuracy: 0.2301 - val_loss: 2.3697 - val_accuracy: 0.2184 - lr: 9.0000e-04
# Epoch 30/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.4244 - accuracy: 0.2215
# Epoch 30: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 2.4215 - accuracy: 0.2207 - val_loss: 2.3123 - val_accuracy: 0.2356 - lr: 9.0000e-04
# Epoch 31/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.3701 - accuracy: 0.2436
# Epoch 31: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.3689 - accuracy: 0.2423 - val_loss: 2.2894 - val_accuracy: 0.1954 - lr: 9.0000e-04
# Epoch 32/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.3731 - accuracy: 0.2377
# Epoch 32: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.3719 - accuracy: 0.2380 - val_loss: 2.2544 - val_accuracy: 0.2213 - lr: 9.0000e-04
# Epoch 33/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.2955 - accuracy: 0.2465
# Epoch 33: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.2970 - accuracy: 0.2473 - val_loss: 2.2216 - val_accuracy: 0.2069 - lr: 9.0000e-04
# Epoch 34/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.3083 - accuracy: 0.2259
# Epoch 34: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.3070 - accuracy: 0.2250 - val_loss: 2.2642 - val_accuracy: 0.2155 - lr: 9.0000e-04
# Epoch 35/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.2526 - accuracy: 0.2583
# Epoch 35: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.2526 - accuracy: 0.2566 - val_loss: 2.1805 - val_accuracy: 0.2270 - lr: 9.0000e-04
# Epoch 36/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.1838 - accuracy: 0.2634
# Epoch 36: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 2.1846 - accuracy: 0.2646 - val_loss: 2.1447 - val_accuracy: 0.2615 - lr: 9.0000e-04
# Epoch 37/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.1819 - accuracy: 0.2818
# Epoch 37: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.1868 - accuracy: 0.2797 - val_loss: 2.1714 - val_accuracy: 0.2730 - lr: 9.0000e-04
# Epoch 38/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.1474 - accuracy: 0.2649
# Epoch 38: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.1503 - accuracy: 0.2638 - val_loss: 2.0811 - val_accuracy: 0.2500 - lr: 9.0000e-04
# Epoch 39/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.1328 - accuracy: 0.2634
# Epoch 39: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.1328 - accuracy: 0.2617 - val_loss: 2.1458 - val_accuracy: 0.2414 - lr: 9.0000e-04
# Epoch 40/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.1000 - accuracy: 0.2789
# Epoch 40: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.0997 - accuracy: 0.2775 - val_loss: 2.1199 - val_accuracy: 0.2270 - lr: 9.0000e-04
# Epoch 41/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.0872 - accuracy: 0.2796
# Epoch 41: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.0901 - accuracy: 0.2825 - val_loss: 2.0775 - val_accuracy: 0.2500 - lr: 9.0000e-04
# Epoch 42/400
# 43/44 [============================>.] - ETA: 0s - loss: 2.0404 - accuracy: 0.2862
# Epoch 42: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 2.0456 - accuracy: 0.2840 - val_loss: 2.1088 - val_accuracy: 0.2098 - lr: 9.0000e-04
# Epoch 43/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.9909 - accuracy: 0.3142
# Epoch 43: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.9927 - accuracy: 0.3142 - val_loss: 1.9970 - val_accuracy: 0.2902 - lr: 9.0000e-04
# Epoch 44/400
# 44/44 [==============================] - ETA: 0s - loss: 1.9986 - accuracy: 0.3005
# Epoch 44: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.9986 - accuracy: 0.3005 - val_loss: 1.9711 - val_accuracy: 0.2414 - lr: 9.0000e-04
# Epoch 45/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.9694 - accuracy: 0.3113
# Epoch 45: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 30ms/step - loss: 1.9702 - accuracy: 0.3113 - val_loss: 2.0230 - val_accuracy: 0.2500 - lr: 9.0000e-04
# Epoch 46/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.9585 - accuracy: 0.3046
# Epoch 46: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.9595 - accuracy: 0.3063 - val_loss: 1.9856 - val_accuracy: 0.2557 - lr: 9.0000e-04
# Epoch 47/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.8997 - accuracy: 0.3321
# Epoch 47: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.9033 - accuracy: 0.3307 - val_loss: 1.9790 - val_accuracy: 0.2557 - lr: 9.0000e-04
# Epoch 48/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.9212 - accuracy: 0.3326
# Epoch 48: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.9163 - accuracy: 0.3350 - val_loss: 1.9239 - val_accuracy: 0.2529 - lr: 9.0000e-04
# Epoch 49/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.9057 - accuracy: 0.3105
# Epoch 49: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.9045 - accuracy: 0.3134 - val_loss: 2.0941 - val_accuracy: 0.2385 - lr: 9.0000e-04
# Epoch 50/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.8936 - accuracy: 0.3186
# Epoch 50: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.8947 - accuracy: 0.3192 - val_loss: 1.9580 - val_accuracy: 0.2500 - lr: 9.0000e-04
# Epoch 51/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.8636 - accuracy: 0.3385
# Epoch 51: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.8655 - accuracy: 0.3372 - val_loss: 1.9468 - val_accuracy: 0.2730 - lr: 9.0000e-04
# Epoch 52/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.8290 - accuracy: 0.3400
# Epoch 52: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.8257 - accuracy: 0.3436 - val_loss: 1.9447 - val_accuracy: 0.2471 - lr: 9.0000e-04
# Epoch 53/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.7844 - accuracy: 0.3451
# Epoch 53: val_loss did not improve from 0.90000
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
# 44/44 [==============================] - 1s 31ms/step - loss: 1.7866 - accuracy: 0.3436 - val_loss: 1.9389 - val_accuracy: 0.2471 - lr: 9.0000e-04
# Epoch 54/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.8330 - accuracy: 0.3414
# Epoch 54: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.8316 - accuracy: 0.3415 - val_loss: 1.9046 - val_accuracy: 0.2672 - lr: 8.1000e-04
# Epoch 55/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.7803 - accuracy: 0.3451
# Epoch 55: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.7841 - accuracy: 0.3444 - val_loss: 1.9181 - val_accuracy: 0.2529 - lr: 8.1000e-04
# Epoch 56/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.8069 - accuracy: 0.3525
# Epoch 56: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.8058 - accuracy: 0.3515 - val_loss: 1.8554 - val_accuracy: 0.2615 - lr: 8.1000e-04
# Epoch 57/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.8184 - accuracy: 0.3326
# Epoch 57: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.8185 - accuracy: 0.3329 - val_loss: 1.8890 - val_accuracy: 0.2759 - lr: 8.1000e-04
# Epoch 58/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.7991 - accuracy: 0.3422
# Epoch 58: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.8003 - accuracy: 0.3400 - val_loss: 1.8883 - val_accuracy: 0.2902 - lr: 8.1000e-04
# Epoch 59/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.7833 - accuracy: 0.3554
# Epoch 59: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.7813 - accuracy: 0.3530 - val_loss: 1.8784 - val_accuracy: 0.2615 - lr: 8.1000e-04
# Epoch 60/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.7309 - accuracy: 0.3716
# Epoch 60: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.7319 - accuracy: 0.3688 - val_loss: 1.8533 - val_accuracy: 0.2816 - lr: 8.1000e-04
# Epoch 61/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.7036 - accuracy: 0.3959
# Epoch 61: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.7075 - accuracy: 0.3918 - val_loss: 1.8939 - val_accuracy: 0.2500 - lr: 8.1000e-04
# Epoch 62/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.6797 - accuracy: 0.3834
# Epoch 62: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.6880 - accuracy: 0.3796 - val_loss: 1.9738 - val_accuracy: 0.2385 - lr: 8.1000e-04
# Epoch 63/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.6898 - accuracy: 0.3760
# Epoch 63: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.6888 - accuracy: 0.3753 - val_loss: 1.8497 - val_accuracy: 0.2730 - lr: 8.1000e-04
# Epoch 64/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.6644 - accuracy: 0.3731
# Epoch 64: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.6708 - accuracy: 0.3674 - val_loss: 1.8399 - val_accuracy: 0.2787 - lr: 8.1000e-04
# Epoch 65/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.6875 - accuracy: 0.3745
# Epoch 65: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.6902 - accuracy: 0.3767 - val_loss: 1.8872 - val_accuracy: 0.2328 - lr: 8.1000e-04
# Epoch 66/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.6421 - accuracy: 0.3951
# Epoch 66: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.6470 - accuracy: 0.3918 - val_loss: 1.8902 - val_accuracy: 0.2644 - lr: 8.1000e-04
# Epoch 67/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.6268 - accuracy: 0.3826
# Epoch 67: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.6254 - accuracy: 0.3832 - val_loss: 1.8904 - val_accuracy: 0.2845 - lr: 8.1000e-04
# Epoch 68/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.6384 - accuracy: 0.3856
# Epoch 68: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.6370 - accuracy: 0.3875 - val_loss: 1.9489 - val_accuracy: 0.2529 - lr: 8.1000e-04
# Epoch 69/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5938 - accuracy: 0.4121
# Epoch 69: val_loss did not improve from 0.90000
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
# 44/44 [==============================] - 1s 31ms/step - loss: 1.5959 - accuracy: 0.4105 - val_loss: 1.9057 - val_accuracy: 0.2759 - lr: 8.1000e-04
# Epoch 70/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5889 - accuracy: 0.4113
# Epoch 70: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.5949 - accuracy: 0.4069 - val_loss: 1.8388 - val_accuracy: 0.2989 - lr: 7.2900e-04
# Epoch 71/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5910 - accuracy: 0.4187
# Epoch 71: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.5889 - accuracy: 0.4170 - val_loss: 1.9347 - val_accuracy: 0.2759 - lr: 7.2900e-04
# Epoch 72/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5872 - accuracy: 0.4180
# Epoch 72: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.5901 - accuracy: 0.4155 - val_loss: 1.8414 - val_accuracy: 0.2586 - lr: 7.2900e-04
# Epoch 73/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5852 - accuracy: 0.4003
# Epoch 73: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.5839 - accuracy: 0.4004 - val_loss: 1.7788 - val_accuracy: 0.3190 - lr: 7.2900e-04
# Epoch 74/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5972 - accuracy: 0.4069
# Epoch 74: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 1.6001 - accuracy: 0.4069 - val_loss: 1.8280 - val_accuracy: 0.2845 - lr: 7.2900e-04
# Epoch 75/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5796 - accuracy: 0.4069
# Epoch 75: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 36ms/step - loss: 1.5778 - accuracy: 0.4062 - val_loss: 1.8882 - val_accuracy: 0.2672 - lr: 7.2900e-04
# Epoch 76/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5859 - accuracy: 0.4084
# Epoch 76: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 36ms/step - loss: 1.5867 - accuracy: 0.4091 - val_loss: 1.7622 - val_accuracy: 0.2816 - lr: 7.2900e-04
# Epoch 77/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5609 - accuracy: 0.4238
# Epoch 77: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 1.5546 - accuracy: 0.4277 - val_loss: 1.7805 - val_accuracy: 0.2787 - lr: 7.2900e-04
# Epoch 78/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5041 - accuracy: 0.4474
# Epoch 78: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 35ms/step - loss: 1.5050 - accuracy: 0.4443 - val_loss: 1.7936 - val_accuracy: 0.2787 - lr: 7.2900e-04
# Epoch 79/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5403 - accuracy: 0.4268
# Epoch 79: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 34ms/step - loss: 1.5360 - accuracy: 0.4270 - val_loss: 1.9281 - val_accuracy: 0.2356 - lr: 7.2900e-04
# Epoch 80/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4849 - accuracy: 0.4518
# Epoch 80: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.4904 - accuracy: 0.4493 - val_loss: 1.9122 - val_accuracy: 0.2529 - lr: 7.2900e-04
# Epoch 81/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5306 - accuracy: 0.4290
# Epoch 81: val_loss did not improve from 0.90000
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
# 44/44 [==============================] - 1s 32ms/step - loss: 1.5301 - accuracy: 0.4277 - val_loss: 1.8223 - val_accuracy: 0.2874 - lr: 7.2900e-04
# Epoch 82/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.5007 - accuracy: 0.4444
# Epoch 82: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.4972 - accuracy: 0.4464 - val_loss: 1.7312 - val_accuracy: 0.3046 - lr: 6.5610e-04
# Epoch 83/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4568 - accuracy: 0.4555
# Epoch 83: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 36ms/step - loss: 1.4582 - accuracy: 0.4565 - val_loss: 1.8223 - val_accuracy: 0.2615 - lr: 6.5610e-04
# Epoch 84/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4675 - accuracy: 0.4511
# Epoch 84: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 35ms/step - loss: 1.4673 - accuracy: 0.4493 - val_loss: 1.7799 - val_accuracy: 0.2816 - lr: 6.5610e-04
# Epoch 85/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4921 - accuracy: 0.4238
# Epoch 85: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 35ms/step - loss: 1.4887 - accuracy: 0.4263 - val_loss: 1.8134 - val_accuracy: 0.2759 - lr: 6.5610e-04
# Epoch 86/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4145 - accuracy: 0.4739
# Epoch 86: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 35ms/step - loss: 1.4178 - accuracy: 0.4723 - val_loss: 1.8440 - val_accuracy: 0.2787 - lr: 6.5610e-04
# Epoch 87/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4354 - accuracy: 0.4562
# Epoch 87: val_loss did not improve from 0.90000
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
# 44/44 [==============================] - 2s 35ms/step - loss: 1.4360 - accuracy: 0.4543 - val_loss: 1.8398 - val_accuracy: 0.2529 - lr: 6.5610e-04
# Epoch 88/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4785 - accuracy: 0.4349
# Epoch 88: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 34ms/step - loss: 1.4795 - accuracy: 0.4349 - val_loss: 1.8188 - val_accuracy: 0.2586 - lr: 5.9049e-04
# Epoch 89/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4303 - accuracy: 0.4599
# Epoch 89: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.4320 - accuracy: 0.4587 - val_loss: 1.7782 - val_accuracy: 0.2874 - lr: 5.9049e-04
# Epoch 90/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4057 - accuracy: 0.4570
# Epoch 90: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 1.4035 - accuracy: 0.4572 - val_loss: 1.8170 - val_accuracy: 0.2874 - lr: 5.9049e-04
# Epoch 91/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4130 - accuracy: 0.4761
# Epoch 91: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 35ms/step - loss: 1.4095 - accuracy: 0.4766 - val_loss: 1.7973 - val_accuracy: 0.3046 - lr: 5.9049e-04
# Epoch 92/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3874 - accuracy: 0.5033
# Epoch 92: val_loss did not improve from 0.90000
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 0.0005314410547725857.
# 44/44 [==============================] - 1s 32ms/step - loss: 1.3879 - accuracy: 0.5011 - val_loss: 1.8360 - val_accuracy: 0.2816 - lr: 5.9049e-04
# Epoch 93/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4346 - accuracy: 0.4540
# Epoch 93: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.4417 - accuracy: 0.4508 - val_loss: 1.7524 - val_accuracy: 0.3017 - lr: 5.3144e-04
# Epoch 94/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.4123 - accuracy: 0.4636
# Epoch 94: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.4087 - accuracy: 0.4630 - val_loss: 1.7612 - val_accuracy: 0.3190 - lr: 5.3144e-04
# Epoch 95/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3602 - accuracy: 0.4945
# Epoch 95: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 34ms/step - loss: 1.3620 - accuracy: 0.4953 - val_loss: 1.7282 - val_accuracy: 0.3333 - lr: 5.3144e-04
# Epoch 96/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3857 - accuracy: 0.4930
# Epoch 96: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.3846 - accuracy: 0.4925 - val_loss: 1.7976 - val_accuracy: 0.3017 - lr: 5.3144e-04
# Epoch 97/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3471 - accuracy: 0.4790
# Epoch 97: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.3521 - accuracy: 0.4730 - val_loss: 1.8132 - val_accuracy: 0.2874 - lr: 5.3144e-04
# Epoch 98/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3730 - accuracy: 0.4901
# Epoch 98: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.3749 - accuracy: 0.4889 - val_loss: 1.7605 - val_accuracy: 0.3161 - lr: 5.3144e-04
# Epoch 99/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3837 - accuracy: 0.4857
# Epoch 99: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 1.3850 - accuracy: 0.4860 - val_loss: 1.7666 - val_accuracy: 0.2931 - lr: 5.3144e-04
# Epoch 100/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3417 - accuracy: 0.4871
# Epoch 100: val_loss did not improve from 0.90000
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 0.00047829695977270604.
# 44/44 [==============================] - 1s 32ms/step - loss: 1.3420 - accuracy: 0.4867 - val_loss: 1.7656 - val_accuracy: 0.2989 - lr: 5.3144e-04
# Epoch 101/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3407 - accuracy: 0.4864
# Epoch 101: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 1.3432 - accuracy: 0.4838 - val_loss: 1.7676 - val_accuracy: 0.2845 - lr: 4.7830e-04
# Epoch 102/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3400 - accuracy: 0.4790
# Epoch 102: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.3414 - accuracy: 0.4795 - val_loss: 1.7847 - val_accuracy: 0.3075 - lr: 4.7830e-04
# Epoch 103/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2805 - accuracy: 0.5151
# Epoch 103: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.2782 - accuracy: 0.5162 - val_loss: 1.8085 - val_accuracy: 0.2989 - lr: 4.7830e-04
# Epoch 104/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3015 - accuracy: 0.5254
# Epoch 104: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.3019 - accuracy: 0.5248 - val_loss: 1.8474 - val_accuracy: 0.2960 - lr: 4.7830e-04
# Epoch 105/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2850 - accuracy: 0.5121
# Epoch 105: val_loss did not improve from 0.90000
#
# Epoch 105: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
# 44/44 [==============================] - 2s 36ms/step - loss: 1.2829 - accuracy: 0.5140 - val_loss: 1.7985 - val_accuracy: 0.2787 - lr: 4.7830e-04
# Epoch 106/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.3080 - accuracy: 0.4989
# Epoch 106: val_loss did not improve from 0.90000
# 44/44 [==============================] - 2s 34ms/step - loss: 1.3054 - accuracy: 0.5032 - val_loss: 1.8191 - val_accuracy: 0.2960 - lr: 4.3047e-04
# Epoch 107/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2990 - accuracy: 0.5055
# Epoch 107: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 1.2992 - accuracy: 0.5054 - val_loss: 1.7710 - val_accuracy: 0.2989 - lr: 4.3047e-04
# Epoch 108/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2553 - accuracy: 0.5202
# Epoch 108: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 1.2584 - accuracy: 0.5198 - val_loss: 1.7786 - val_accuracy: 0.2989 - lr: 4.3047e-04
# Epoch 109/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2934 - accuracy: 0.5158
# Epoch 109: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.2926 - accuracy: 0.5155 - val_loss: 1.8223 - val_accuracy: 0.2701 - lr: 4.3047e-04
# Epoch 110/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2908 - accuracy: 0.5063
# Epoch 110: val_loss did not improve from 0.90000
#
# Epoch 110: ReduceLROnPlateau reducing learning rate to 0.00038742052274756136.
# 44/44 [==============================] - 1s 31ms/step - loss: 1.2878 - accuracy: 0.5090 - val_loss: 1.7582 - val_accuracy: 0.3276 - lr: 4.3047e-04
# Epoch 111/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2727 - accuracy: 0.5379
# Epoch 111: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.2770 - accuracy: 0.5363 - val_loss: 1.7623 - val_accuracy: 0.2845 - lr: 3.8742e-04
# Epoch 112/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2458 - accuracy: 0.5364
# Epoch 112: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.2475 - accuracy: 0.5356 - val_loss: 1.7888 - val_accuracy: 0.2874 - lr: 3.8742e-04
# Epoch 113/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2295 - accuracy: 0.5298
# Epoch 113: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.2253 - accuracy: 0.5306 - val_loss: 1.7890 - val_accuracy: 0.3132 - lr: 3.8742e-04
# Epoch 114/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2938 - accuracy: 0.5048
# Epoch 114: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.2960 - accuracy: 0.5040 - val_loss: 1.7622 - val_accuracy: 0.2931 - lr: 3.8742e-04
# Epoch 115/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2451 - accuracy: 0.5217
# Epoch 115: val_loss did not improve from 0.90000
#
# Epoch 115: ReduceLROnPlateau reducing learning rate to 0.0003486784757114947.
# 44/44 [==============================] - 1s 32ms/step - loss: 1.2444 - accuracy: 0.5205 - val_loss: 1.7798 - val_accuracy: 0.3075 - lr: 3.8742e-04
# Epoch 116/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2276 - accuracy: 0.5372
# Epoch 116: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.2301 - accuracy: 0.5370 - val_loss: 1.8010 - val_accuracy: 0.2931 - lr: 3.4868e-04
# Epoch 117/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2180 - accuracy: 0.5511
# Epoch 117: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.2143 - accuracy: 0.5514 - val_loss: 1.7882 - val_accuracy: 0.3017 - lr: 3.4868e-04
# Epoch 118/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2133 - accuracy: 0.5438
# Epoch 118: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 1.2136 - accuracy: 0.5449 - val_loss: 1.7758 - val_accuracy: 0.2701 - lr: 3.4868e-04
# Epoch 119/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2153 - accuracy: 0.5416
# Epoch 119: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 33ms/step - loss: 1.2103 - accuracy: 0.5442 - val_loss: 1.7844 - val_accuracy: 0.2787 - lr: 3.4868e-04
# Epoch 120/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2118 - accuracy: 0.5313
# Epoch 120: val_loss did not improve from 0.90000
#
# Epoch 120: ReduceLROnPlateau reducing learning rate to 0.00031381062290165574.
# 44/44 [==============================] - 1s 33ms/step - loss: 1.2124 - accuracy: 0.5313 - val_loss: 1.7825 - val_accuracy: 0.2931 - lr: 3.4868e-04
# Epoch 121/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2243 - accuracy: 0.5416
# Epoch 121: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.2206 - accuracy: 0.5435 - val_loss: 1.8212 - val_accuracy: 0.2931 - lr: 3.1381e-04
# Epoch 122/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.2101 - accuracy: 0.5453
# Epoch 122: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.2129 - accuracy: 0.5442 - val_loss: 1.7872 - val_accuracy: 0.2759 - lr: 3.1381e-04
# Epoch 123/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.1771 - accuracy: 0.5541
# Epoch 123: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 31ms/step - loss: 1.1747 - accuracy: 0.5550 - val_loss: 1.8092 - val_accuracy: 0.3017 - lr: 3.1381e-04
# Epoch 124/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.1913 - accuracy: 0.5541
# Epoch 124: val_loss did not improve from 0.90000
# 44/44 [==============================] - 1s 32ms/step - loss: 1.1945 - accuracy: 0.5521 - val_loss: 1.8254 - val_accuracy: 0.2874 - lr: 3.1381e-04
# Epoch 125/400
# 43/44 [============================>.] - ETA: 0s - loss: 1.1615 - accuracy: 0.5669Restoring model weights from the end of the best epoch: 95.
#
# Epoch 125: val_loss did not improve from 0.90000
#
# Epoch 125: ReduceLROnPlateau reducing learning rate to 0.0002824295632308349.
# 44/44 [==============================] - 1s 33ms/step - loss: 1.1626 - accuracy: 0.5672 - val_loss: 1.8174 - val_accuracy: 0.3075 - lr: 3.1381e-04
# Epoch 125: early stopping

# %% [markdown]
# ### Learing result
#
# * Visualization of the training and validation results
# * Validation should not much over train validation, because of the augmentation of train data (validation data not)
# * Beware, the best model will be used. This can be from an earlier epoch as the last. (mostly the last -30)

# %%
loss_ges = np.append(loss_ges, history.history['loss'])

if (Training_Percentage > 0):
    val_loss_ges = np.append(val_loss_ges, history.history['val_loss'])
    plt.semilogy(val_loss_ges)

plt.semilogy(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['eval','train'], loc='upper left')
plt.show()

# %% [markdown]
# ### Check the model by data
#
# * The following code uses the trained model to check the deviation for each picture (train + validation).
# * The max_delta can be used to get the accuracy with allowed differences (for instance +/- 0.1)
# * The first (max) 49 false predicted images will be shown
# * a csv-file with all false predicted images will be created. It can be used for relabeling. Usage `python3 -m collectmeteranalog  --labelfile=ana-class100_s1_false_predicted.csv --model=ana-class100_s1q.tflite` (see https://github.com/haverland/collectmeteranalog)

# %%
import numpy as np
from tensorflow import keras
import pandas as pd

max_delta=0.11

def plot_dataset(images, labels, columns=10, rows=5, figsize=(18, 10)):

    fig = plt.figure(figsize=figsize)
    
    for i in range(1, columns*rows +1):
        if (i>len(labels)):
            break
        fig.add_subplot(rows, columns, i)
        plt.title(labels[i-1])  # set title
        plt.imshow((images[i-1]).astype(np.uint8), aspect='1', extent=[0, 1, 0, 1])
        # yellow lines
        ax=plt.gca()
        ax.get_yaxis().set_visible(False) 
        ax.get_xaxis().set_visible(False) 
        
        plt.tight_layout()
    plt.show()

def plot_divergence(divergationset, title1, nb_classes):
    fig = plt.figure(figsize=(40, 10))
    fig.suptitle(title1)
    plt.bar(np.arange (0, nb_classes/10, 0.1), divergationset, width=0.09, align='center')
    plt.ylabel('count')
    plt.xlabel('digit class')
    plt.xticks(np.arange(0, nb_classes/10, 0.1))
    return fig

#model = keras.models.load_model(TFliteNamingAndVersion + "_best.h5")

classes = model.predict(x_data.astype(np.float32))
predictions = np.argmax(classes, axis=1).reshape(-1)/10

# 9.9 <> 0 = 0.1 and 1.1 <> 1.2 = 0.1
differences = np.minimum(np.abs(predictions-y_data), np.abs(predictions-(10-y_data)))
# used for filtering
false_differences = differences>max_delta
# only differences bigger than delta. so small differences can be ignored in early stages
false_predicted = differences[false_differences]
false_images = x_data[false_differences]
false_labels = [ "Expected: " + str(y1) + "\n Predicted: " + str(p) + "\n" + str(f)[-26:-4] for y1, p, f in zip(y_data[false_differences], predictions[false_differences], f_data[false_differences])]
false_files = [ f for f in  f_data[false_differences]]

print(f"Tested images: {len(y_data)}. {len(false_predicted)} false predicted. Accuracy is: {1-len(false_predicted)/len(y_data)}")
# plot the differences (max difference can only be 5.0)
plot_divergence(np.bincount(np.array(np.round(false_predicted*10)).astype(int), minlength=51), "Divergation of false predicted", 51)

# plot the false predicted images
plot_dataset(np.array(false_images), false_labels, columns=7, rows=7, figsize=(18,18))
#print(false_files)
fpf = pd.DataFrame(false_files)

# the csv can be used with collectmeterdigits to fix labels
# python3 -m collectmeteranalog  --labelfile=ana-class100_0166_s2_false_predicted.csv --model=ana-class100_0166_s2_q.tflite
fpf.to_csv(TFliteNamingAndVersion + '_false_predicted.csv')
# Out:
# 23/55 [===========>..................] - ETA: 0s
# 2024-04-08 19:45:47.716299: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 55/55 [==============================] - 0s 6ms/step
# Tested images: 1739. 180 false predicted. Accuracy is: 0.8964922369177688

# %% [markdown]
# ### Save the model
#
# * Save the model to the file with the "tflite" file format
# * quantize the model and store it as -q.tflite

# %%
FileName = TFliteNamingAndVersion

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open(FileName + ".tflite", "wb").write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpwm89ergw/assets
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpwm89ergw/assets
# 2024-04-08 19:45:52.574545: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2024-04-08 19:45:52.574559: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2024-04-08 19:45:52.574823: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpwm89ergw
# 2024-04-08 19:45:52.578005: I tensorflow/cc/saved_model/reader.cc:91] Reading meta graph with tags { serve }
# 2024-04-08 19:45:52.578012: I tensorflow/cc/saved_model/reader.cc:132] Reading SavedModel debug info (if present) from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpwm89ergw
# 2024-04-08 19:45:52.585190: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2024-04-08 19:45:52.588649: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2024-04-08 19:45:52.703355: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpwm89ergw
# 2024-04-08 19:45:52.738827: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 164002 microseconds.
# 2024-04-08 19:45:52.770532: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 481128

# %%
from pathlib import Path
import tensorflow as tf

FileName = TFliteNamingAndVersion + "_q" + ".tflite"

def representative_dataset():
    for n in range(np.size(x_data,0)):
      data = np.expand_dims(x_data[n], axis=0)
      yield [data.astype(np.float32)]
        
converter2 = tf.lite.TFLiteConverter.from_keras_model(model)
converter2.representative_dataset = representative_dataset
converter2.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter2.convert()

open(FileName, "wb").write(tflite_quant_model)
print(FileName)
Path(FileName).stat().st_size
# Out:
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpkornt37e/assets
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpkornt37e/assets
# /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.9/site-packages/tensorflow/lite/python/convert.py:887: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2024-04-08 19:45:55.001053: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2024-04-08 19:45:55.001066: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# ana-class100_0172_s2_q.tflite
# 2024-04-08 19:45:55.001205: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpkornt37e
# 2024-04-08 19:45:55.004483: I tensorflow/cc/saved_model/reader.cc:91] Reading meta graph with tags { serve }
# 2024-04-08 19:45:55.004492: I tensorflow/cc/saved_model/reader.cc:132] Reading SavedModel debug info (if present) from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpkornt37e
# 2024-04-08 19:45:55.015054: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2024-04-08 19:45:55.131463: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpkornt37e
# 2024-04-08 19:45:55.166390: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 165184 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# 137144
