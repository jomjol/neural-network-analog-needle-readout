# %% [markdown]
# # CNN Training
#
# Target of this code is to train a CNN network to extract the needle position of an analog needle device.
#
# ### Preparing the training
# * First all libraries are loaded
#     * It is assumed, that they are installed during the Python setup
# * matplotlib is set to print the output inline in the jupyter notebook

# %%
########### Basic Parameters for Running: ################################
    
TFlite_Version  = "16.00.01"   
TFlite_MainType = "ana-cont"
TFlite_Size     = "s1"
Training_Percentage = 0.05              # 0.0 = Use all Images for Training

##########################################################################

import os
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import numpy as np
from sklearn.utils import shuffle
from tensorflow.python import keras
from tensorflow.python.keras import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Conv2D, MaxPool2D, Flatten, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import History 
import math
from PIL import Image 

from augmentation import augmentation, no_augmentation
from plot_functions import plot_dataset, plot_dataset_analog

loss_ges = np.array([])
val_loss_ges = np.array([])

# %matplotlib inline
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load training data
# * The data is expected in the "Input_dir"
# * Picture size must be 32x32 with 3 color channels (RGB)
# * The filename contains the informations needed for training in the first 3 digits::
# * Typical filename:
#     * x.y-zzzz.jpg
#     * e.g. "4.6_Lfd-1406_zeiger3_2019-06-02T050011"
#
# |Place holder | Meaning                     | Usage        |
# |------------- |-----------------------------|--------------|
# | **x.y**          | readout value               | **to be learned** |
# | zzzz        | additional information              | not needed   |
#
# * The images are stored in the x_data[]
# * The expected output for each image in the corresponding y_data[]
#     * The periodic nature is reflected in a **sin/cos coding**, which allows to restore the angle/counter value with an arctan later on.
#
# * The last step is a shuffle (from sklearn.utils) as the filenames are on order due to the encoding of the expected analog readout in the filename

# %%
Input_dir='data_resize_all'

files = glob.glob(Input_dir + '/*.*')
x_data = []
y_data = []

for aktfile in files:
    test_image = Image.open(aktfile)
    test_image = np.array(test_image, dtype="float32")
    test_image = np.reshape(test_image, (32,32,3))
    base = os.path.basename(aktfile)
    target_number = (float(base[0:3])) / 10
    target_sin = math.sin(target_number * math.pi * 2)
    target_cos = math.cos(target_number * math.pi * 2)

    x_data.append(test_image)
    zw = np.array([target_sin, target_cos])
    y_data.append(zw)

x_data = np.array(x_data)
y_data = np.array(y_data)
print(x_data.shape)
print(y_data.shape)

x_data, y_data = shuffle(x_data, y_data)

if (Training_Percentage > 0):
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)
else:
    x_train = x_data
    y_train = y_data
# Out:
# (909, 32, 32, 3)
# (909, 2)

# %% [markdown]
# ### Define the model
#
# The layout of the network ist a typcial CNN network with alternating **Conv2D** and **MaxPool2D** layers. Finished after **flattening** with additional **Dense** layer.
#
# #### Important
# * Shape of the input layer: (32, 32, 3)
# * Shape of the output layer: (2) - sin and cos

# %%
inputs = tf.keras.Input(shape=(32, 32, 3))

x = tf.keras.layers.BatchNormalization()(inputs)
x = tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation="relu")(x)
x = tf.keras.layers.MaxPool2D(pool_size=(4,4))(x)

x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation="relu")(x)
x = tf.keras.layers.MaxPool2D(pool_size=(2,2))(x)

x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation="relu")(x)
x = tf.keras.layers.MaxPool2D(pool_size=(2,2))(x)

x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.2)(x)

x = tf.keras.layers.Dense(128,activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.2)(x)

x = tf.keras.layers.Dense(64,activation="relu")(x)
output = tf.keras.layers.Dense(2)(x)

model = tf.keras.Model(inputs=inputs, outputs=output)
model.compile(loss=keras.losses.mean_squared_error, optimizer=tf.keras.optimizers.Adadelta(learning_rate=1.0, rho=0.95), metrics = ["accuracy"])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 3)      │            12 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 8, 8, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 8, 8, 32)       │        25,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 4, 4, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 63,502 (248.05 KB)
#  Trainable params: 62,856 (245.53 KB)
#  Non-trainable params: 646 (2.52 KB)

# %% [markdown]
# # Training
# The input pictures are randomly scattered for brightness and pixel shift variations. These is implemented with a ImageDataGenerator.
#
#
# The training is splitted into two steps:
# 1. Variation of the brightness only
# 2. Variation of brightness and Pixel Shift

# %%
Batch_Size = 8
Shift_Range = 0
Brightness_Range = 0.3

# train data
print("Train data")
#train_iterator = augmentation(x_data, y_data)
train_iterator = augmentation(x_train, y_train,
                             _Batch_Size          = Batch_Size, 
                             _width_shift_range   = 0, 
                             _height_shift_range  = 0,
                             _brightness_range    = [1-Brightness_Range, 1+Brightness_Range],
                             _zoom_range_In       = 0,
                             _zoom_range_Out      = 0,
                             _rotation_range      = 0,
                             _channel_shift_range = 0,
                             _shear_range         = 0,
                             _preprocessing       = False)
plot_dataset_analog(train_iterator)     

if (Training_Percentage > 0):
    # validation data
    validation_iterator = no_augmentation(x_test, y_test)
    print("  ")
    print("  ")
    print("Validation data")
    plot_dataset_analog(validation_iterator, rows=3)
# Out:
# Train data
#
#
# Validation data

# %% [markdown]
# ### Step 1: Brigthness scattering only

# %%
Epoch_Anz = 30

if (Training_Percentage > 0):
    history = model.fit(train_iterator, validation_data = validation_iterator, epochs = Epoch_Anz)
else:
    history = model.fit(train_iterator, epochs = Epoch_Anz)
# Out:
# Epoch 1/30
# C:\Users\Muell\anaconda3\envs\py311-tf218\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5502 - loss: 1.2003 - val_accuracy: 0.5652 - val_loss: 0.6795
# Epoch 2/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5706 - loss: 0.7167 - val_accuracy: 0.6957 - val_loss: 0.3584
# Epoch 3/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6211 - loss: 0.5633 - val_accuracy: 0.6739 - val_loss: 0.3893
# Epoch 4/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5985 - loss: 0.5317 - val_accuracy: 0.7826 - val_loss: 0.4319
# Epoch 5/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6488 - loss: 0.5233 - val_accuracy: 0.8043 - val_loss: 0.3101
# Epoch 6/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6317 - loss: 0.4940 - val_accuracy: 0.7609 - val_loss: 0.3133
# Epoch 7/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7298 - loss: 0.3459 - val_accuracy: 0.8261 - val_loss: 0.2603
# Epoch 8/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7391 - loss: 0.3761 - val_accuracy: 0.9348 - val_loss: 0.1642
# Epoch 9/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7514 - loss: 0.3316 - val_accuracy: 0.9348 - val_loss: 0.3369
# Epoch 10/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8118 - loss: 0.2805 - val_accuracy: 0.9348 - val_loss: 0.1778
# Epoch 11/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7763 - loss: 0.2588 - val_accuracy: 0.9130 - val_loss: 0.1434
# Epoch 12/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8168 - loss: 0.2341 - val_accuracy: 0.9130 - val_loss: 0.1299
# Epoch 13/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8439 - loss: 0.1982 - val_accuracy: 0.9565 - val_loss: 0.1317
# Epoch 14/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8330 - loss: 0.1774 - val_accuracy: 0.9565 - val_loss: 0.1015
# Epoch 15/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8843 - loss: 0.1593 - val_accuracy: 0.9565 - val_loss: 0.0826
# Epoch 16/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8720 - loss: 0.1418 - val_accuracy: 0.9783 - val_loss: 0.0849
# Epoch 17/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8952 - loss: 0.1209 - val_accuracy: 0.9783 - val_loss: 0.0809
# Epoch 18/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8978 - loss: 0.1172 - val_accuracy: 0.9783 - val_loss: 0.0958
# Epoch 19/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9064 - loss: 0.0969 - val_accuracy: 0.9348 - val_loss: 0.0795
# Epoch 20/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9129 - loss: 0.0872 - val_accuracy: 0.9565 - val_loss: 0.0813
# Epoch 21/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9094 - loss: 0.0884 - val_accuracy: 0.9783 - val_loss: 0.0527
# Epoch 22/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9045 - loss: 0.0837 - val_accuracy: 0.9130 - val_loss: 0.0632
# Epoch 23/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9336 - loss: 0.0726 - val_accuracy: 0.9565 - val_loss: 0.0733
# Epoch 24/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9266 - loss: 0.0714 - val_accuracy: 0.9783 - val_loss: 0.0654
# Epoch 25/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9388 - loss: 0.0642 - val_accuracy: 0.9783 - val_loss: 0.0537
# Epoch 26/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9172 - loss: 0.0648 - val_accuracy: 0.9565 - val_loss: 0.0484
# Epoch 27/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9300 - loss: 0.0542 - val_accuracy: 0.9565 - val_loss: 0.0747
# Epoch 28/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9277 - loss: 0.0604 - val_accuracy: 0.9565 - val_loss: 0.0454
# Epoch 29/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9360 - loss: 0.0583 - val_accuracy: 0.9783 - val_loss: 0.0358
# Epoch 30/30
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9503 - loss: 0.0529 - val_accuracy: 0.9783 - val_loss: 0.0356

# %% [markdown]
# ### Step 1: Learing result
#
# * Visualization of the training and validation results

# %%
loss_ges = np.append(loss_ges, history.history['loss'])

if (Training_Percentage > 0):
    val_loss_ges = np.append(val_loss_ges, history.history['val_loss'])
    plt.semilogy(val_loss_ges)

plt.semilogy(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['eval','train'], loc='upper left')
plt.show()

# %%
Batch_Size = 8
Shift_Range = 3
Brightness_Range = 0.3
Zoom_Range = 0.1

# train data
print("Train data")
#train_iterator = augmentation(x_data, y_data)
train_iterator = augmentation(x_train, y_train,
                             _Batch_Size          = Batch_Size, 
                             _width_shift_range   = Shift_Range, 
                             _height_shift_range  = Shift_Range,
                             _brightness_range    = [1-Brightness_Range, 1+Brightness_Range],
                             _zoom_range_In       = Zoom_Range,
                             _zoom_range_Out      = Zoom_Range,
                             _rotation_range      = 0,
                             _channel_shift_range = 0,
                             _shear_range         = 0,
                             _preprocessing       = True)
plot_dataset_analog(train_iterator)     

if (Training_Percentage > 0):
    # validation data
    validation_iterator = no_augmentation(x_test, y_test)
    print("  ")
    print("  ")
    print("Validation data")
    plot_dataset_analog(validation_iterator, rows=3)
# Out:
# Train data
#
#
# Validation data

# %% [markdown]
# ### Step 2: Brigthness and Pixel Shift scattering
# Here a higher number of epochs is used to reach the minimum loss function

# %%
Epoch_Anz = 500

if (Training_Percentage > 0):
    history = model.fit(train_iterator, validation_data = validation_iterator, epochs = Epoch_Anz)
else:
    history = model.fit(train_iterator, epochs = Epoch_Anz)
# Out:
# Epoch 1/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6577 - loss: 0.4091 - val_accuracy: 0.9348 - val_loss: 0.0836
# Epoch 2/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7027 - loss: 0.3333 - val_accuracy: 0.9565 - val_loss: 0.0982
# Epoch 3/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7400 - loss: 0.2994 - val_accuracy: 0.9783 - val_loss: 0.0697
# Epoch 4/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7949 - loss: 0.2527 - val_accuracy: 0.9783 - val_loss: 0.0582
# Epoch 5/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8311 - loss: 0.2281 - val_accuracy: 0.9783 - val_loss: 0.0671
# Epoch 6/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8347 - loss: 0.2067 - val_accuracy: 0.9565 - val_loss: 0.0530
# Epoch 7/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8326 - loss: 0.1780 - val_accuracy: 0.9565 - val_loss: 0.0579
# Epoch 8/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8910 - loss: 0.1632 - val_accuracy: 0.9783 - val_loss: 0.0702
# Epoch 9/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8492 - loss: 0.1675 - val_accuracy: 0.9783 - val_loss: 0.0531
# Epoch 10/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8504 - loss: 0.1565 - val_accuracy: 0.9565 - val_loss: 0.0554
# Epoch 11/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8707 - loss: 0.1440 - val_accuracy: 0.9783 - val_loss: 0.0489
# Epoch 12/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8874 - loss: 0.1305 - val_accuracy: 0.9783 - val_loss: 0.0486
# Epoch 13/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8780 - loss: 0.1450 - val_accuracy: 0.9783 - val_loss: 0.0732
# Epoch 14/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8598 - loss: 0.1533 - val_accuracy: 0.9783 - val_loss: 0.0703
# Epoch 15/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8720 - loss: 0.1346 - val_accuracy: 0.9783 - val_loss: 0.0512
# Epoch 16/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9012 - loss: 0.1107 - val_accuracy: 0.9783 - val_loss: 0.0436
# Epoch 17/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8669 - loss: 0.1251 - val_accuracy: 0.9783 - val_loss: 0.0562
# Epoch 18/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9025 - loss: 0.1211 - val_accuracy: 0.9783 - val_loss: 0.0498
# Epoch 19/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9128 - loss: 0.1208 - val_accuracy: 1.0000 - val_loss: 0.0389
# Epoch 20/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9031 - loss: 0.1086 - val_accuracy: 0.9565 - val_loss: 0.0608
# Epoch 21/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8988 - loss: 0.1289 - val_accuracy: 0.9783 - val_loss: 0.0466
# Epoch 22/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9002 - loss: 0.1036 - val_accuracy: 0.9783 - val_loss: 0.0458
# Epoch 23/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9190 - loss: 0.1181 - val_accuracy: 0.9565 - val_loss: 0.0432
# Epoch 24/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9038 - loss: 0.1128 - val_accuracy: 0.9783 - val_loss: 0.0379
# Epoch 25/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8958 - loss: 0.0939 - val_accuracy: 0.9783 - val_loss: 0.0431
# Epoch 26/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9208 - loss: 0.1019 - val_accuracy: 0.9783 - val_loss: 0.0365
# Epoch 27/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9070 - loss: 0.0962 - val_accuracy: 0.9783 - val_loss: 0.0366
# Epoch 28/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9064 - loss: 0.0895 - val_accuracy: 0.9783 - val_loss: 0.0359
# Epoch 29/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9187 - loss: 0.0778 - val_accuracy: 0.9783 - val_loss: 0.0348
# Epoch 30/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9154 - loss: 0.0994 - val_accuracy: 1.0000 - val_loss: 0.0285
# Epoch
500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9525 - loss: 0.0419 - val_accuracy: 0.9783 - val_loss: 0.0122
# Epoch 206/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9609 - loss: 0.0286 - val_accuracy: 0.9783 - val_loss: 0.0164
# Epoch 207/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9534 - loss: 0.0341 - val_accuracy: 1.0000 - val_loss: 0.0171
# Epoch 208/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9598 - loss: 0.0329 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 209/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9503 - loss: 0.0292 - val_accuracy: 0.9783 - val_loss: 0.0135
# Epoch 210/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9519 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0145
# Epoch 211/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9551 - loss: 0.0297 - val_accuracy: 1.0000 - val_loss: 0.0152
# Epoch 212/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9584 - loss: 0.0368 - val_accuracy: 1.0000 - val_loss: 0.0133
# Epoch 213/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9380 - loss: 0.0342 - val_accuracy: 1.0000 - val_loss: 0.0141
# Epoch 214/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9572 - loss: 0.0342 - val_accuracy: 0.9783 - val_loss: 0.0158
# Epoch 215/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9552 - loss: 0.0318 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 216/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9646 - loss: 0.0311 - val_accuracy: 0.9783 - val_loss: 0.0126
# Epoch 217/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9332 - loss: 0.0361 - val_accuracy: 0.9783 - val_loss: 0.0116
# Epoch 218/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9447 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 219/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9489 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 220/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9520 - loss: 0.0360 - val_accuracy: 0.9783 - val_loss: 0.0212
# Epoch 221/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9477 - loss: 0.0333 - val_accuracy: 0.9348 - val_loss: 0.0205
# Epoch 222/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9500 - loss: 0.0261 - val_accuracy: 0.9783 - val_loss: 0.0206
# Epoch 223/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9567 - loss: 0.0331 - val_accuracy: 1.0000 - val_loss: 0.0159
# Epoch 224/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9422 - loss: 0.0300 - val_accuracy: 0.9783 - val_loss: 0.0111
# Epoch 225/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9573 - loss: 0.0342 - val_accuracy: 0.9783 - val_loss: 0.0203
# Epoch 226/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9516 - loss: 0.0290 - val_accuracy: 0.9783 - val_loss: 0.0209
# Epoch 227/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9500 - loss: 0.0328 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 228/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9494 - loss: 0.0335 - val_accuracy: 1.0000 - val_loss: 0.0136
# Epoch 229/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9554 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 0.0169
# Epoch 230/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9519 - loss: 0.0343 - val_accuracy: 1.0000 - val_loss: 0.0185
# Epoch 231/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9431 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0182
# Epoch 232/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9453 - loss: 0.0300 - val_accuracy: 1.0000 - val_loss: 0.0160
# Epoch 233/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9625 - loss: 0.0290 - val_accuracy: 0.9783 - val_loss: 0.0127
# Epoch 234/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9451 - loss: 0.0353 - val_accuracy: 0.9783 - val_loss: 0.0121
# Epoch 235/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9619 - loss: 0.0299 - val_accuracy: 0.9783 - val_loss: 0.0164
# Epoch 236/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9473 - loss: 0.0360 - val_accuracy: 0.9783 - val_loss: 0.0124
# Epoch 237/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9515 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 0.0162
# Epoch 238/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9370 - loss: 0.0364 - val_accuracy: 0.9783 - val_loss: 0.0192
# Epoch 239/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9574 - loss: 0.0340 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 240/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9511 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 0.0178
# Epoch 241/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9594 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0240
# Epoch 242/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9507 - loss: 0.0284 - val_accuracy: 0.9783 - val_loss: 0.0234
# Epoch 243/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9598 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 0.0314
# Epoch 244/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9557 - loss: 0.0294 - val_accuracy: 1.0000 - val_loss: 0.0253
# Epoch 245/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9483 - loss: 0.0299 - val_accuracy: 1.0000 - val_loss: 0.0196
# Epoch 246/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9543 - loss: 0.0404 - val_accuracy: 1.0000 - val_loss: 0.0213
# Epoch 247/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9539 - loss: 0.0327 - val_accuracy: 0.9783 - val_loss: 0.0197
# Epoch 248/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9640 - loss: 0.0264 - val_accuracy: 0.9783 - val_loss: 0.0198
# Epoch 249/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9526 - loss: 0.0211 - val_accuracy: 0.9783 - val_loss: 0.0165
# Epoch 250/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9511 - loss: 0.0428 - val_accuracy: 0.9783 - val_loss: 0.0151
# Epoch 251/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9609 - loss: 0.0290 - val_accuracy: 1.0000 - val_loss: 0.0231
# Epoch 252/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9568 - loss: 0.0284 - val_accuracy: 1.0000 - val_loss: 0.0225
# Epoch 253/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9590 - loss: 0.0223 - val_accuracy: 1.0000 - val_loss: 0.0138
# Epoch 254/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9630 - loss: 0.0318 - val_accuracy: 1.0000 - val_loss: 0.0234
# Epoch 255/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9635 - loss: 0.0272 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 256/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9526 - loss: 0.0342 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 257/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9625 - loss: 0.0277 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 258/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9393 - loss: 0.0374 - val_accuracy: 0.9783 - val_loss: 0.0110
# Epoch 259/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9404 - loss: 0.0350 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 260/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9527 - loss: 0.0296 - val_accuracy: 1.0000 - val_loss: 0.0200
# Epoch 261/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9474 - loss: 0.0342 - val_accuracy: 1.0000 - val_loss: 0.0218
# Epoch 262/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9525 - loss: 0.0373 - val_accuracy: 1.0000 - val_loss: 0.0235
# Epoch 263/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9641 - loss: 0.0338 - val_accuracy: 1.0000 - val_loss: 0.0278
# Epoch 264/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9422 - loss: 0.0270 - val_accuracy: 0.9783 - val_loss: 0.0193
# Epoch 265/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9598 - loss: 0.0260 - val_accuracy: 0.9783 - val_loss: 0.0134
# Epoch 266/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9534 - loss: 0.0331 - val_accuracy: 1.0000 - val_loss: 0.0176
# Epoch 267/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9630 - loss: 0.0261 - val_accuracy: 0.9783 - val_loss: 0.0235
# Epoch 268/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9394 - loss: 0.0252 - val_accuracy: 1.0000 - val_loss: 0.0298
# Epoch 269/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9475 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 270/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9696 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0235
# Epoch 271/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9540 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 0.0145
# Epoch 272/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9511 - loss: 0.0273 - val_accuracy: 0.9783 - val_loss: 0.0128
# Epoch 273/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.
500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9620 - loss: 0.0315 - val_accuracy: 0.9783 - val_loss: 0.0130
# Epoch 320/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9716 - loss: 0.0219 - val_accuracy: 0.9783 - val_loss: 0.0134
# Epoch 321/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9630 - loss: 0.0271 - val_accuracy: 0.9783 - val_loss: 0.0107
# Epoch 322/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9473 - loss: 0.0258 - val_accuracy: 0.9783 - val_loss: 0.0103
# Epoch 323/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9663 - loss: 0.0220 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 324/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9575 - loss: 0.0235 - val_accuracy: 0.9783 - val_loss: 0.0108
# Epoch 325/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9712 - loss: 0.0216 - val_accuracy: 0.9783 - val_loss: 0.0122
# Epoch 326/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9575 - loss: 0.0294 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 327/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9463 - loss: 0.0328 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 328/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9625 - loss: 0.0212 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 329/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9578 - loss: 0.0254 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 330/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9502 - loss: 0.0260 - val_accuracy: 0.9783 - val_loss: 0.0111
# Epoch 331/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9621 - loss: 0.0203 - val_accuracy: 0.9783 - val_loss: 0.0070
# Epoch 332/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9559 - loss: 0.0211 - val_accuracy: 0.9783 - val_loss: 0.0086
# Epoch 333/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9522 - loss: 0.0283 - val_accuracy: 0.9783 - val_loss: 0.0082
# Epoch 334/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9590 - loss: 0.0205 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 335/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9658 - loss: 0.0250 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 336/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9563 - loss: 0.0253 - val_accuracy: 0.9783 - val_loss: 0.0120
# Epoch 337/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9609 - loss: 0.0265 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 338/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9608 - loss: 0.0221 - val_accuracy: 0.9783 - val_loss: 0.0105
# Epoch 339/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9603 - loss: 0.0272 - val_accuracy: 0.9783 - val_loss: 0.0100
# Epoch 340/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9441 - loss: 0.0235 - val_accuracy: 0.9783 - val_loss: 0.0101
# Epoch 341/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9372 - loss: 0.0313 - val_accuracy: 0.9783 - val_loss: 0.0143
# Epoch 342/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9514 - loss: 0.0220 - val_accuracy: 0.9783 - val_loss: 0.0135
# Epoch 343/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9584 - loss: 0.0254 - val_accuracy: 0.9783 - val_loss: 0.0131
# Epoch 344/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9625 - loss: 0.0205 - val_accuracy: 0.9783 - val_loss: 0.0129
# Epoch 345/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9499 - loss: 0.0290 - val_accuracy: 0.9783 - val_loss: 0.0119
# Epoch 346/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9459 - loss: 0.0276 - val_accuracy: 0.9783 - val_loss: 0.0118
# Epoch 347/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9628 - loss: 0.0293 - val_accuracy: 0.9783 - val_loss: 0.0091
# Epoch 348/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9703 - loss: 0.0261 - val_accuracy: 0.9783 - val_loss: 0.0081
# Epoch 349/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9529 - loss: 0.0269 - val_accuracy: 0.9783 - val_loss: 0.0140
# Epoch 350/500
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9696 - loss: 0.0214 - val_accuracy: 0.9783 - val_loss: 0.0106
# Epoch 351/500
#  46/108 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9198 - loss: 0.0291

# %% [markdown]
# ### Overall Learing results (Step 1 & Step 2)

# %%
loss_ges = np.append(loss_ges, history.history['loss'])

if (Training_Percentage > 0):
    val_loss_ges = np.append(val_loss_ges, history.history['val_loss'])
    plt.semilogy(val_loss_ges)


plt.semilogy(loss_ges)
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','eval'], loc='upper left')
plt.show()

# %% [markdown]
# ### Check the model by hand
#
# * The following code uses the trained model to check the deviation for each picture.
# * The evaluation takes the periodic character of the results into account (dev1 ... dev2).
# * Images, that have a bigger deviation as the parameter "deviation_max_list" are printed in a list to check the picture and labeling itself

# %%
Input_dir='data_resize_all'
#Input_dir='test_result'
files = glob.glob(Input_dir + '/*.*')
res = []
stat_Anz = []
stat_Abweichung = []
i = 0
deviation_max_list = 0.15

for i in range(100):
    stat_Anz.append(0)
    stat_Abweichung.append(0)

for aktfile in sorted(files):
    base = os.path.basename(aktfile)
    target = (float(base[0:3])) / 10
    
    target_sin = math.sin(target * math.pi * 2)
    target_cos = math.cos(target * math.pi * 2)

    test_image = Image.open(aktfile)
    test_image = np.array(test_image, dtype="float32")
    img = np.reshape(test_image,[1,32,32,3])
    classes = model.predict(img, verbose=0)
    
    out_sin = classes[0][0]  
    out_cos = classes[0][1]
    out_target = (np.arctan2(out_sin, out_cos)/(2*math.pi)) % 1

    dev_sin = target_sin - out_sin
    dev_cos = target_cos - out_cos
    dev_target = target - out_target
    
    if abs(dev_target + 1) < abs(dev_target):
        out_target = out_target - 1
        dev_target = target - out_target
    else:
        if abs(dev_target - 1) < abs(dev_target):
            out_target = out_target + 1
            dev_target = target - out_target
            
    target_int = int ((float(base[0:3])) * 10)
    stat_Abweichung[target_int] = stat_Abweichung[target_int] + dev_target  
    stat_Anz[target_int] = stat_Anz[target_int] + 1
               
    res.append(np.array([target, out_target, dev_target, out_sin, out_cos, i]))
    if abs(dev_target) > deviation_max_list:
        print(aktfile + " " + str(target) + " " + str(out_target) +  " " + str(dev_target))

    
for i in range(100):
    stat_Abweichung[i] = stat_Abweichung[i] / stat_Anz[i]

res = np.asarray(res)
res_step_1 = res

# %% [markdown]
# ## Results

# %%
plt.plot(res[:,3])
plt.plot(res[:,4])
plt.title('Result')
plt.ylabel('value')
plt.xlabel('#Picture')
plt.legend(['sin', 'cos'], loc='lower left')
plt.show()

# %%
plt.plot(res[:,0])
plt.plot(res[:,1])
plt.title('Result')
plt.ylabel('Counter Value')
plt.xlabel('#Picture')
plt.legend(['Orginal', 'Prediction'], loc='upper left')
plt.show()

# %%
plt.plot(stat_Abweichung)
plt.title('Result')
plt.ylabel('Counter Value')
plt.xlabel('#Picture')
plt.legend(['Orginal', 'Prediction'], loc='upper left')
plt.show()

# %%
plt.plot(stat_Anz)
plt.title('Result')
plt.ylabel('Counter Value')
plt.xlabel('#Picture')
plt.legend(['Orginal', 'Prediction'], loc='upper left')
plt.show()

# %% [markdown]
# ### Deviation from Expected Value

# %%
plt.plot(res[:,2])
plt.title('Deviation')
plt.ylabel('Deviation from expected value')
plt.xlabel('#Picture')
plt.legend(['Deviation'], loc='upper left')
#plt.ylim(-0.3, 0.3)
plt.show()

statistic = np.array([np.mean(res[:,2]), np.std(res[:,2]), np.min(res[:,2]), np.max(res[:,2])])
print(statistic)
# Out:
# [ 0.0013  0.0117 -0.0556  0.0979]

# %% [markdown]
# ### Save the model
#
# * Save the model to the file with the "h5" file format

# %%
model.export("test", "tf_saved_model")  # replace tf.saved_model.save with this line
# Out:
# INFO:tensorflow:Assets written to: test\assets
# INFO:tensorflow:Assets written to: test\assets
# Saved artifact at 'test'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   2814744775184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744773456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744773648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744773264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744774608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744774224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744775760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744776528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744774416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744774800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744776336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744777872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744776720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744776912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744772880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744777680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744777296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744780752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744782480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744781712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744782672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744781904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744784208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744784976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744785552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744783056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744785744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744782288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744787280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744788048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744788240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814744787472: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
FileName = TFlite_MainType + "_" + TFlite_Version + "_" + TFlite_Size + ".tflite"

converter = tf.lite.TFLiteConverter.from_saved_model("test")
tflite_model = converter.convert()
print(FileName)
open(FileName, "wb").write(tflite_model)
# Out:
# ana-cont_16.00.01_s1.tflite
# 255584

# %%
from pathlib import Path
import tensorflow as tf

FileName = FileName = TFlite_MainType + "_" + TFlite_Version + "_" + TFlite_Size + "_q.tflite"

def representative_dataset():
    for n in range(x_data.shape[0]):
      data = np.expand_dims(x_data[n], axis=0)
      yield [data.astype(np.float32)]

converter = tf.lite.TFLiteConverter.from_saved_model("test")
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter._experimental_disable_per_channel_quantization_for_dense_layers = True
tflite_quant_model = converter.convert()

open(FileName, "wb").write(tflite_quant_model)
print(FileName)
Path(FileName).stat().st_size
# Out:
# ana-cont_16.00.01_s1_q.tflite
# 73168
